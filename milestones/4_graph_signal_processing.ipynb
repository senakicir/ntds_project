# %% [markdown]
# # [NTDS'18] milestone 4: graph signal processing
# [ntds'18]: https://github.com/mdeff/ntds_2018
#
# [Rodrigo Pena](https://people.epfl.ch/254838), [EPFL LTS2](http://lts2.epfl.ch)

# %% [markdown]
# ## Students
#
# * Team: `32`
# * Students: `George Adaimi, Okan Altingovde, Isinsu Katircioglu, Sena Kiciroglu`
# * Dataset: `FMA`

# %% [markdown]
# ## Rules
#
# * Milestones have to be completed by teams. No collaboration between teams is allowed.
# * Textual answers shall be short. Typically one to two sentences.
# * Code has to be clean.
# * You cannot import any other library than we imported.
# * When submitting, the notebook is executed and the results are stored. I.e., if you open the notebook again it should show numerical results and plots. We won't be able to execute your notebooks.
# * The notebook is re-executed from a blank state before submission. That is to be sure it is reproducible. You can click "Kernel" then "Restart & Run All" in Jupyter.

# %% [markdown]
# ## Objective
#
# The goal of this milestone is to do some Graph Signal Processing (GSP) on the data of your project.
#
# ### A note about plotting
#
# There are several questions in this milestone that ask you to plot a signal on your network.
# There are several ways from which you could approach it.
# In all cases, compute the position of the nodes a single time at the beginning, as this is likely to be a costly operation.
# Using a single layout for all the graph plots will also make it easier to compare the plots.
# Indeed, the only thing changing between plots is the signal displayed.
# You can represent the features/labels lying on the graph via node **colors**.
# To do so, make sure to have a consistent color map throughout and remember to display a colorbar and scale in all plots, so that we can tell what numbers the colors represent.
#
# * An option is to use the **Laplacian eigenmaps** that you have seen in the previous milestone to embed your graph on the plane. For example:
#   ```
#   from matplotlib import pyplot as plt
#   plt.scatter(eigenvectors[:, 1], eigenvectors[:, 2], c=signal, alpha=0.5)
#   plt.colorbar()
#   ```
# * Another option is to use the plotting capabilities of **[NetworkX](https://networkx.github.io)**.
#   See the documentation of its [drawing methods](https://networkx.github.io/documentation/stable/reference/drawing.html).
#   For example:
#   ```
#   import networkx as nx
#   graph = nx.from_scipy_sparse_matrix(adjacency)
#   coords = nx.spring_layout(graph)  # Force-directed layout.
#   coords = eigenvectors[:, 1:3]  # Laplacian eigenmaps.
#   nx.draw_networkx_nodes(graph, coords, node_size=60, node_color=signal)
#   nx.draw_networkx_edges(graph, coords, alpha=0.3)
#   ```
# * Another option is to use the plotting capabilities of the **[PyGSP](https://github.com/epfl-lts2/pygsp)**, a Python package for Graph Signal Processing.
#   **Note that your are forbidden to use the PyGSP for anything else than plotting.**
#   See the documentation of its [plotting utilities](https://pygsp.readthedocs.io/en/stable/reference/plotting.html).
#   For example:
#   ```
#   import pygsp as pg
#   graph = pg.graphs.Graph(adjacency)
#   graph.set_coordinates('spring')  # Force-directed layout.
#   graph.set_coordinates(eigenvectors[:, 1:3])  # Laplacian eigenmaps.
#   graph.plot_signal(signal)
#   ```
# * Yet another option is to save your graph on disk, use **[Gephi](https://gephi.org)** externally, to visualize the graph, save the graph with the Gephi coordinates and finally load the nodes coordinates back into the notebook.
#
# We encourage you to try all the above methods before making your choice. Then be consistent and use only one throughout the milestone.
# NetworkX and PyGSP should already be installed in your environement. If that's not the case, install with `conda install networkx pygsp` (after activating the `ntds_2018` environment).

# %% [markdown]
# ## 0 - Load your network

# %%
# %matplotlib inline

# %% [markdown]
# If you get a `No module named 'pyunlocbox'` error when running the below cell, install the [pyunlocbox](https://github.com/epfl-lts2/pyunlocbox) with `conda install pyunlocbox` (after activating the `ntds_2018` environment).

# %%
import numpy as np
from scipy import sparse
import scipy.sparse.linalg
from matplotlib import pyplot as plt
from pyunlocbox import functions, solvers

import pygsp as pg

# %% [markdown]
# For this milestone, all we will need is a set of features/labels for each of the nodes on the network, as well as the Laplacian, $L,$ and Gradient, $\nabla_G,$ matrices that you have computed for your network while working on milestone 3.
#
# Import those objects in the cell below (or recompute the Laplacian and Gradient from your stored adjacency matrix, if you wish).
#
# _Note_: If your features/labels are not floating-point numbers, please convert them. For example, if your data has labels "cat" and "dog" for nodes that represent cats or dogs, respectively, you may assign the number `1.0` for the label "cat" and the number `-1.0` for the label "dog".

# %%
adjacency =  np.load('features_onlyMFCCCorrelation.npy')# the adjacency matrix
n_nodes = adjacency.shape[0]
n_edges =  np.count_nonzero(adjacency)//2# the number of edges in the network

D = np.diag(adjacency.sum(axis=1))
L = D - adjacency #combinatorial laplacian
sqrt_D = np.power(np.linalg.inv(D),0.5)

# %%
#Find incidence matrix. Since our graph is undirected, we chose to only consider the upper right 
#triangle of our adjacency matrix when finding the gradient.
normalized_incidence = np.zeros((n_nodes, n_edges))
edge_map = np.full((n_nodes, n_nodes), -1)
edge_indices = np.where(adjacency > 0)
next_edge = 0
for i, j in (zip(edge_indices[0], edge_indices[1])):
    if edge_map[i, j] == -1:
        edge_map[i, j] = next_edge
        edge_map[j, i] = next_edge
        normalized_incidence[i, next_edge] = np.sqrt(adjacency[i,j])*sqrt_D[i,i]
        next_edge += 1
    else:
        normalized_incidence[i, edge_map[i, j]] = -np.sqrt(adjacency[i,j])*sqrt_D[i,i]

# %%
#Question part
laplacian =sparse.csr_matrix(sqrt_D@L@sqrt_D)
gradient = sparse.csr_matrix(np.transpose(normalized_incidence))
labels = np.load('labels.npy') #the labels for hip-hop and rock (-1 and 1)
print('Number of nodes: ', n_nodes)
# Out:
# Number of nodes:  2000

# %% [markdown]
# ## 1 - Graph Fourier Transform
#
# In this section we will observe how your feature/label vector looks like in the "Graph Fourier" domain.

# %% [markdown]
# ### Question 1
#
# Compute the Fourier basis vectors and the Laplacian eigenvalues. Make sure to order those from smaller to larger, $\lambda_0 \leq \lambda_1 \leq \dots \leq \lambda_{N-1},$ and use the same ordering for the Fourier basis vectors.

# %%
eigenvalues, eigenvectors = np.linalg.eigh(laplacian.toarray())
## Sorting Eigenvalues and EigenVectors
sorted_indexes = eigenvalues.argsort()
eigenvalues = np.array(eigenvalues[sorted_indexes])
eigenvectors = np.array(eigenvectors[sorted_indexes])

e = eigenvalues # Ordered Laplacian eigenvalues.
U = eigenvectors # Ordered graph Fourier basis.

# %%
#We use it only for plotting!
graph = pg.graphs.Graph(adjacency, lap_type = 'normalized')
graph.set_coordinates('spring')

# %% [markdown]
# Plot the first 3 and the last Fourier basis vectors as signals on your graph. Clearly indicate which plot belongs to which basis vector.

# %%
# Your code here.
plot_list = [0,1,2,-1]
for i, plot_ind in enumerate(plot_list):
    graph.plot_signal(np.asarray(U)[:, plot_ind])
    plt.title('Eigenvector %d, (eigenvalue %.3f)' %((plot_ind+1 if plot_ind>= 0 else n_nodes), np.asarray(e)[plot_ind]))

# %% [markdown]
# ### Question 2
#
# What can you observe in terms of local variations when comparing the basis vectors corresponding to the smallest eigenvalues to those corresponding to the largest eigenvalue? How would this justify the interpretation of the eigenvalues as "graph frequencies"?

# %% [markdown]
# **Our answer**:
#
# * In our graph we can see a large clustered part and a few outlier nodes. Generally, we are concerned with the local variations within the large clustered part (since this is where most of our nodes lie).
# * The eigenvector corresponding to the smallest eigenvalue (1st) doesn't show much spectral fluctuations within the large clustered part of the graph (the values shown on the colormap are very close). The 3rd and last eigenvector don't give a lot of information since it seems to be localized on the outlier part of the graph. However, the eigenvector corresponding to the 2nd eigenvalue captures some of the spectral fluctuations within the large clustered part.
# * Looking at the eigenvectors plotted above, we cannot really interpret eigenvalues behaving as graph frequencies. Ideally, we would have seen very little spectral fluctuation in the graph corresponding to the smallest eigenvalue, and these fluctuations would increase as the frequency increased. However, since some of the eigenvectors localize on the outlier part of the graph, it is difficult to see any fluctuation in their graphs. Therefore, it is very difficult to justify since our graph is so irregular (as opposed to a simple grid-like graph).
# * Skipping ahead to question 4, we have seen that the 5th eigenvalue really captures the spectral fluctuations within the large clustered part with a larger local variation. We have plotted the basis signal corresponding to that eigenvalue below.

# %%
plot_list = [4]
for i, plot_ind in enumerate(plot_list):
    graph.plot_signal(np.asarray(U)[:, plot_ind])
    plt.title('Eigenvector %d, (eigenvalue %.3f)' %((plot_ind+1 if plot_ind>= 0 else n_nodes), np.asarray(e)[plot_ind]))

# %% [markdown]
# ### Question 3
#
# Implement a function that returns the Graph Fourier Transform (GFT) of a given vector $x \in \mathbb{R}^{N},$ with respect to your graph, and a function that computes the corresponding inverse GFT (iGFT).

# %%
def GFT(x):
    return eigenvectors.T@np.array(x) # Your code here.

def iGFT(x):
    return eigenvectors@np.array(x) # Your code here.

# %% [markdown]
# ### Question 4
#
# Plot your feature/label vector as a signal on your graph

# %%
# Your code here.
graph.plot_signal(labels)
plt.title("labels")
plt.show()
plt.close()

# %% [markdown]
# Plot the absolute values of the GFT of your feature/label signal as a function of the graph eigenvalues. Make sure to add a marker indicating the position of each graph eigenvalue, and remember to properly name the axes.

# %%
# Your code here.
gft_of_labels = np.abs(GFT(labels))

fig = plt.figure()
plt.plot(e, gft_of_labels, marker = "*")
plt.xlabel("eigenvalues")
plt.ylabel("GFT of label")
plt.title("Spectral Analysis of Labels")
plt.show()
plt.close(fig)

# %% [markdown]
# ### Question 5
#
# Discuss the behavior of the GFT that you plotted in the last question via comparing the plot of your label signal and those of the Fourier basis of Question 1. Would you consider your labels a "low-pass" or "high-pass" signal, or yet something else entirely?

# %% [markdown]
# **Our answer:**
#
# * Looking at the plot in Question 4, the GFT peaks at eigenvalue (frequency) 0.451. When we look at the fourier plots, we notice that the fourier basis corresponding to eigenvalue 0.451 clusters our graph nicely. Indeed, below we have shown clustering performed using the 5th eigenvector (in a similar manner to the Fiedler vector). The accuracy is 81%.
# * We would consider our labels to be a low-pass signal. We have high response values especially between frequencies 0.3 and 0.6.

# %%
#do clustering to demonstrate that our labels generally lie at the 0.451 frequency (which corresponds to the 5th eigenvalue)
clustering_vec = np.asarray(U)[:,4]
clusters = np.zeros([n_nodes,])
clusters[clustering_vec>0] = -1
clusters[clustering_vec<=0] = 1

#plotting
graph.plot_signal(labels)
plt.title('labels')
graph.plot_signal(clusters)
plt.title('our clustering according to eigenvector 5')
accuracy = (len((((clusters == labels).nonzero())[0]))/n_nodes)*100
print('Clustering accuracy based on 5th eigenvector: ', accuracy)
# Out:
# Clustering accuracy based on 5th eigenvector:  80.85

# %% [markdown]
# ## 2 - Filtering on graphs
#
# In this section we will check how filtered Dirac impulses diffuse on your graph.

# %% [markdown]
# ### Question 6
#
# Implement the following three filter kernels and the graph filtering operation.
#
# - The **heat kernel** is supposed to take in a vector of eigenvalues `e` and a parameter `t` and output a vector of evaluations of the heat kernel at those eigenvalues (see the course slides for help).
# - The **inverse filter** kernel is supposed to take in a vector of eigenvalues `e` and a parameter `t` and implement spectrally the  filter defined in the node domain by $f_{out}  = (I + t L)^{-1} f_{in},$ where $f_{in}, f_{out} \in \mathbb{R}^{N}$ are, repectively, the input and output signals to the filter.
# - The **rectangle kernel** takes in a vector of eigenvalues `e` and parameters `l_min` and `l_max` and returns `1.0` at coordinates satisfying $(e[l] \geq l_{min}) \wedge (e[l] \leq l_{max}),$ and `0.0` otherwise.
# - The **graph filtering** operation takes a graph signal $x \in \mathbb{R}^{N}$, a spectral graph `kernel` and a set of keyworded variables, and returns the corresponding filtered signal.
#     - _Hint:_ Remember that you have implemented the `GFT` and `iGFT` operations in Question 3.
#     - The `**kwargs` is a placeholder to collect supplementary pairs of keyword-values that are not known by the implementation before execution time.
#       The `kwargs` variable is a dictionary whose keyes and values are the parameter names and values.
#       This is useful to allow both `graph_filter(x, heat_kernel, tau=1.0)` and `graph_filter(x, rectangle_kernel, lambda_min=0.0, lambda_max=1.0)` to be valid calls from the same implementation.
#       One can then defer the keyword-value assignment to the `kernel` call: `foo = kernel(bar, **kwargs)`.

# %%
def heat_kernel(e, t):
    return np.exp(-e*t)

def inverse_kernel(e, t):
    return np.power(np.ones((n_nodes,))+t*e,-1)

def rectangle_kernel(e, l_min, l_max): 
    kernel = np.zeros([n_nodes,])
    kernel[np.logical_and(e >= l_min, e <= l_max)] = 1
    return kernel

def graph_filter(x, kernel, **kwargs):
    gft_x = GFT(x)
    out_kernel = kernel(e, **kwargs)
    filtered_x = iGFT(out_kernel*gft_x)
    return filtered_x

# %% [markdown]
# ### Question 7
#
# Plot all three filter kernels in the spectral domain. Remember to properly name the axes and title the plots. Choose filter parameters that best approximate the behavior of the GFT of your feature/label signal (as seen in Question 4).

# %%
# Your code here.
#Determine each kernel
t_heat = 0.8
t_inv = 0.5
l_min = 0.2
l_max = 1
heat_kernel_res = heat_kernel(e, t=t_heat)
inverse_kernel_res = inverse_kernel(e, t=t_inv)
rectangle_kernel_res = rectangle_kernel(e, l_min = l_min, l_max = l_max)

#plot
fig = plt.figure()
plt.plot(e, heat_kernel_res, marker = "*")
plt.title("Heat kernel")
plt.xlabel("Frequency (Eigenvalues)")
plt.ylabel("Kernel value")
plt.show()
plt.close(fig)

fig = plt.figure()
plt.plot(e, inverse_kernel_res, marker = "*")
plt.title("Inverse kernel")
plt.xlabel("Frequency (Eigenvalues)")
plt.ylabel("Kernel value")
plt.show()
plt.close(fig)

fig = plt.figure()
plt.plot(e, rectangle_kernel_res, marker = "*")
plt.title("Rectangle kernel")
plt.xlabel("Frequency (Eigenvalues)")
plt.ylabel("Kernel value")
plt.show()
plt.close(fig)

# %% [markdown]
# ### Question 8
#
# Consider two Dirac impulses arbitrarily placed on your graph. Plot their filtered versions by the three filter kernels implemented in Question 6.

# %%
# Your code here.
#Arbitrarily placed 2 dirac impulses
t_heat = 5
t_inv = 7
l_min = 0.3
l_max = 1
diracs = np.zeros([n_nodes,])
dirac_pos = [20, 1000]
diracs[dirac_pos] = 1

#filtered signal results
filtered_s_heat = graph_filter(diracs, heat_kernel, t=t_heat)
filtered_s_inv = graph_filter(diracs, inverse_kernel, t=t_inv)
filtered_s_rect = graph_filter(diracs, rectangle_kernel, l_min = l_min, l_max = l_max)

#plotting
graph.plot_signal(filtered_s_heat)
plt.title("Heat")
graph.plot_signal(filtered_s_inv)
plt.title("Inverse")
graph.plot_signal(filtered_s_rect)
plt.title("Rectangular")
plt.show()
plt.close()

# %% [markdown]
# Comment on the "diffusion" of the Diracs induced by the filters. What does it say about the "communication" of information across your network? Relate that to the network connectivity measures that you analyzed during the previous milestones.

# %% [markdown]
# **Our answer:**
# * We can see that the information is communicated from the two diracs to the surrounding connected nodes.
# * In the plots below, we can see that as we increase t, the diffusion to the surrounding nodes increases. In the heat kernel response plot's colorbar, we can see that the highest value of our signal is 1 (these are the two diracs, and they are giving off a signal at two nodes.) As t increases, the highest value drops (observed from colorbar), but the spread increases.
# * The speed of the diffusion decreases as t increases (as observed by the lack of change between the colorbars of t=100 and t=1000).

# %%
#Show information diffusing over time with heat kernel
t_list = [0, 1, 5, 100, 1000]
for t in t_list:
    #filtered signal results
    filtered_s_heat = graph_filter(diracs, heat_kernel, t=t)
    #plotting
    graph.plot_signal(filtered_s_heat)
    plt.title("Heat with t=" + str(t))

# %% [markdown]
# ## 3 - De-noising
#
# In this section we will add some centered Gaussian noise to your feature/label signal and attempt to recover it.

# %% [markdown]
# ### Question 9
#
# In the cell below, set the noise variance $\sigma^2$ by making sure that the signal-to-noise ratio $SNR = \frac{\operatorname{Var}(\text{labels})}{\sigma^2}$ is about  $1.5$.
#
# _Note:_ Actually, you might want to play with the noise variance here and set it to different values and see how the denoising filters behave.

# %%
SNR = 1.5
noise_variance = np.var(labels)/SNR # Your code here.
noise_alone = noise_variance * np.random.randn(n_nodes)
noisy_measurements = labels + noise_variance * np.random.randn(n_nodes)

# %% [markdown]
# ### Question 10
#
# In the denoising setting, a common graph signal processing assumption is that the signal $z$ that we want to recover is "smooth", in the sense that $\|\nabla_G z\|_2 = \sqrt{z^{\top} L z}$ is small, while remaining "close" to the measurements that we start with. This leads to denoising by solving the following optimization problem:
#
# $$
# z^\star = \text{arg} \, \underset{z \in \mathbb{R}^{N}}{\min} \, \|z - y\|_2^2 + \gamma z^{\top} L z,
# $$
#
# where $y \in \mathbb{R}^{N}$ is the vector of noisy measurements.
#
# Derive the close form solution to this problem giving $z^\star$ as a function of $y$, $\gamma$ and $L$. Does this solution correspond to any graph filtering operation that you know?

# %% [markdown]
# **Your answer here.**
# $$
# z^\star = \text{arg} \, \underset{z \in \mathbb{R}^{N}}{\min} \big(z^{\top}z - z^{\top}y - y^{\top}z + y^{\top}y + \gamma z^{\top} L z \big)
# $$
#
# $$
# \frac{\partial\big(z^{\top}z - z^{\top}y - y^{\top}z + y^{\top}y + \gamma z^{\top} L z \big) }{\partial z} = 0
# $$
#
# $$
# 2z - 2y + \gamma(L + L^{\top})z = 0
# $$
#
# $$
# (2I + \gamma L + \gamma L^{\top})z = 2y
# $$
#
# $$
# z^\star = (2I + \gamma L + \gamma L^{\top})^{-1}2y
# $$
#
# Since L is symmetric we can write $L^{\top} = L$ which follows
#
# $$
# z^\star = (2I + 2\gamma L)^{-1}2y
# $$
#
# $$
# z^\star = (I + \gamma L)^{-1}y
# $$
#
# *This solution corresponds to inverse filter kernel with t = $\gamma$.

# %% [markdown]
# ### Question 11
#
# Now, denoise the noisy measurements by passing them through the filters that you implemented in Question 6. Choose the filter parameters based on the behavior of the GFT of your original label signal (this is the prior knowledge that you input to the problem).

# %%
## Filter Parameters
t_heat = 0.8
t_inv = 0.5
l_min = 0.2
l_max = 1
z_heat_denoised = graph_filter(noisy_measurements, heat_kernel, t=t_heat) # Your code here.
z_inv_denoised = graph_filter(noisy_measurements, inverse_kernel, t=t_inv) # Your code here.
z_rect_denoised = graph_filter(noisy_measurements, rectangle_kernel, l_min = l_min, l_max = l_max)# Your code here.

# %% [markdown]
# Plot, on your graph, the original label signal, the noisy measurements, and the three denoised version obtained above. Report on each plot the value of the corresponding relative error
# $$
# \text{rel-err} = \frac{\|\text{labels} - z \|_2}{\|\text{labels}\|_2},
# $$
# where $z$ is the plotted signal.

# %%
# Your code here.
def relative_error(signal):
    return np.linalg.norm((labels-signal))/np.linalg.norm(labels)

# %%
#plotting
graph.plot_signal(labels)
plt.title("Original Labels, rel_err {:.2E}".format(relative_error(labels)))
graph.plot_signal(noisy_measurements)
plt.title("Noisy Measurements, rel_err {:.2E}".format(relative_error(noisy_measurements)))
graph.plot_signal(z_heat_denoised)
plt.title("Heat denoised, rel_err {:.2E}".format(relative_error(z_heat_denoised)))
graph.plot_signal(z_inv_denoised)
plt.title("Inverse denoised, rel_err {:.2E}".format(relative_error(z_inv_denoised)))
graph.plot_signal(z_rect_denoised)
plt.title("Rectangle denoised, rel_err {:.2E}".format(relative_error(z_rect_denoised)))
plt.show()
plt.close()

# %% [markdown]
# Finally, overlay on the same plot the GFT of all five signals above.

# %%
# Your code here.
gft_of_noisy_measurements = np.abs(GFT(noisy_measurements))
gft_of_heat = np.abs(GFT(z_heat_denoised))
gft_of_inv = np.abs(GFT(z_inv_denoised))
gft_of_rect = np.abs(GFT(z_rect_denoised))

# plotting  
fig = plt.figure()
plt.plot(e, gft_of_labels, marker = "*",label='Labels')
plt.plot(e, gft_of_noisy_measurements, marker = "*",label='Noisy Measurements')
plt.plot(e, gft_of_heat, marker = "*",label='Heat GFT')
plt.plot(e, gft_of_inv, marker = "o",label='Inverse GFT')
plt.plot(e, gft_of_rect, marker = "x",label='Rect GFT')
plt.xlabel("eigenvalues")
plt.ylabel("GFT of Signal")
plt.legend(loc='upper left')
plt.show()
plt.close(fig)

# %% [markdown]
# ### Question 12
#
# Comment on which denoised version seems to best match the original label signal. What is the underlying assumption behind the three filtering approaches? Do you think it holds for your label signal? Why?

# %% [markdown]
# **Our answer:**
#
# * As you can see in the plot above, our signal has higher responses at the lower frequences and has some small non-zero values corresponding to the middle frequencies.  Noise generally has higher values in the higher frequencies (as shown in the plot below).
# * The version denoised by the inverse kernel seems to be the best match to the original label signal and it is followed by the heat kernel. They are both low pass filters, but the heat kernel behaves as a sharper low pass filter and supresses the middle frequency values more.
# * The rectangle kernel would work better if we didn't have frequency responses in the mid frequencies. Then we could use the rectangle filter to filter out the noise but not lose any information about our underlying signal.

# %%
#GFT of noise
gft_of_noise = np.abs(GFT(noise_alone))
fig = plt.figure()
plt.plot(e, gft_of_noise, marker = "*",label='Noise')
plt.show()
plt.close(fig)

# %% [markdown]
# ## 4 - Transductive learning
#
# It is often the case in large networks that we can only afford to query properties/labels on a small subset of nodes. Nonetheless, if the underlying labels signal is "regular" enough, we might still be able to recover a good approximation of it by solving an offline variational problem, with constraints on the values of the measured nodes.
#
# In this section, we will be interested in solving such transductive learning problems by minimizing a (semi-) p-norm of the graph gradient applied to the signal of interest:
#
# $$
# \text{arg} \, \underset{z|_S = y}{\min} \|\nabla_G z\|_p^p,
# $$
#
# where $S$ is the set of measured nodes.
#
# In English, we can say that we are looking for solutions with small "aggregated local variations", as measured by $\|\nabla_G z\|_p^p = \sum_{i=1}^{n} \sum_{j=1}^{n} \left( \sqrt{W_{ij}} |z[i] - z[j]| \right)^p,$ while satisfying the measurement constraints $z[i] = y[i]$ for $i \in S.$
#
# We will work with two cases, according to the choices $p=1$ or $p=2.$ For $p=1,$ the problem is known as "interpolation by graph total-variation minimization," whereas for $p=2$ it is sometimes called "interpolation by Tikhonov regularization".
#
# In order to solve these variational problems with the black-box solver provided to you, you will use the [pyunlocbox](https://pyunlocbox.readthedocs.io). This toolbox implements iterative solvers based on so-called ["proximal-splitting"](https://en.wikipedia.org/wiki/Proximal_gradient_method) methods.

# %% [markdown]
# ### Question 13
#
# Throughout this section, we will consider only a binarized version of your label signal. If your variable `labels` currently has values other than $\{-1, 1\},$ threshold them so that those are the only values taken in this vector. This can be done for example by choosing a number $t \in \mathbb{R}$ and then setting $\text{labels_bin}[i] = 1$ if $\text{labels}[i] \geq t$ and $\text{labels_bin}[i] = 0$ otherwise.

# %%
#Our labels are  already binary
labels_bin = labels # Your code here.

# %% [markdown]
# Now, subsample this binarized label signal by $70\%$ by choosing, uniformly at random, $30\%$ of the nodes whose labels we will keep.
#
# You will do this by computing a "measurement mask" vector `w` with `1.0`'s at the measured coordinates, and $0.0$'s otherwise.

# %%
#Form measurement mask vector
mn_ratio = 0.3
m = int(mn_ratio * n_nodes)  # Number of measurements.
np.random.seed(5)
w= np.zeros((n_nodes,))
w[np.random.choice(n_nodes, m, replace=False)] = 1# Your code here.

# %% [markdown]
# Plot the subsampled signal on the graph. _Hint:_ you might want to set to `numpy.nan` the values of the un-measured nodes for a cleaner plot.

# %%
# Your code here.
#subsample our labels
labels_for_graphing = labels_bin.astype(np.float32)
labels_for_graphing[w==0] = np.nan

#plot
graph.plot_signal(labels_for_graphing)
plt.title("Subsampled Signal on the graph")
plt.show()
plt.close()
# Out:
# /Users/kicirogl/anaconda3/envs/ntds_2018/lib/python3.7/site-packages/numpy/core/_methods.py:32: RuntimeWarning: invalid value encountered in reduce
#   return umr_minimum(a, axis, None, out, keepdims, initial)
# /Users/kicirogl/anaconda3/envs/ntds_2018/lib/python3.7/site-packages/numpy/core/_methods.py:28: RuntimeWarning: invalid value encountered in reduce
#   return umr_maximum(a, axis, None, out, keepdims, initial)

# %% [markdown]
# ### Interlude
#
# For the solution of the variational problems you can use the following function as a "black-box".
#
# You will just need to provide a `gradient` matrix (which you should already have from Section 0), and an orthogonal projection operator `P` onto the span of the measured coordinates (made precise in the next question).

# %%
def graph_pnorm_interpolation(gradient, P, x0=None, p=1., **kwargs):
    r"""
    Solve an interpolation problem via gradient p-norm minimization.

    A signal :math:`x` is estimated from its measurements :math:`y = A(x)` by solving
    :math:`\text{arg}\underset{z \in \mathbb{R}^n}{\min}
    \| \nabla_G z \|_p^p \text{ subject to } Az = y` 
    via a primal-dual, forward-backward-forward algorithm.

    Parameters
    ----------
    gradient : array_like
        A matrix representing the graph gradient operator
    P : callable
        Orthogonal projection operator mapping points in :math:`z \in \mathbb{R}^n` 
        onto the set satisfying :math:`A P(z) = A z`.
    x0 : array_like, optional
        Initial point of the iteration. Must be of dimension n.
        (Default is `numpy.random.randn(n)`)
    p : {1., 2.}
    kwargs :
        Additional solver parameters, such as maximum number of iterations
        (maxit), relative tolerance on the objective (rtol), and verbosity
        level (verbosity). See :func:`pyunlocbox.solvers.solve` for the full
        list of options.

    Returns
    -------
    x : array_like
        The solution to the optimization problem.

    """
    
    grad = lambda z: gradient.dot(z)
    div = lambda z: gradient.transpose().dot(z)

    # Indicator function of the set satisfying :math:`y = A(z)`
    f = functions.func()
    f._eval = lambda z: 0
    f._prox = lambda z, gamma: P(z)

    # :math:`\ell_1` norm of the dual variable :math:`d = \nabla_G z`
    g = functions.func()
    g._eval = lambda z: np.sum(np.abs(grad(z)))
    g._prox = lambda d, gamma: functions._soft_threshold(d, gamma)

    # :math:`\ell_2` norm of the gradient (for the smooth case)
    h = functions.norm_l2(A=grad, At=div)

    stepsize = (0.9 / (1. + scipy.sparse.linalg.norm(gradient, ord='fro'))) ** p

    solver = solvers.mlfbf(L=grad, Lt=div, step=stepsize)

    if p == 1.:
        problem = solvers.solve([f, g, functions.dummy()], x0=x0, solver=solver, **kwargs)
        return problem['sol']
    if p == 2.:
        problem = solvers.solve([f, functions.dummy(), h], x0=x0, solver=solver, **kwargs)
        return problem['sol']
    else:
        return x0

# %% [markdown]
# ### Question 14
#
# During the iterations of the algorithm used for solving the variational problem, we have to make sure that the labels at the measured nodes stay the same. We will do this by means of an operator `P` which, given a vector $a \in \mathbb{R}^{N},$ returns another vector $b \in \mathbb{R}^{N}$ satisfying $b[i] = \text{labels_bin}[i]$ for every node $i$ in the set $S$ of known labels, and $b[i] = a[i]$ otherwise. Write in the cell below the function for this orthogonal projection operator `P`.
#
# _Hint:_ remember you have already computed the mask `w`.

# %%
def P(a):
    # Your code here.
    b = a.copy()
    b[w==1] = labels_bin[w==1]
    return b

# %% [markdown]
# ### Question 15
#
# Solve the variational problems for $p = 1$ and $p = 2$. Record the solution for the $1-$norm minimization under `sol_1norm_min` and the one for $2-$norm minimization under `sol_2norm_min`.
#
# Compute also binarized versions of these solutions by thresholding the values with respect to $0$, that is, non-negative values become `1.0`, while negative values become `-1.0`. Store those binarized versions under `sol_1norm_bin` and `sol_2norm_bin`, respectively.

# %%
sol_1norm_min = graph_pnorm_interpolation(gradient, P, x0=np.random.randn(n_nodes), p=1.)# Your code here.
sol_2norm_min = graph_pnorm_interpolation(gradient, P, x0=np.random.randn(n_nodes), p=2.) # Your code here.

threshold = 0

#threshold results
sol_1norm_bin = np.zeros(sol_1norm_min.shape)
sol_1norm_bin[sol_1norm_min >= threshold] = 1 # Your code here.
sol_1norm_bin[sol_1norm_min < threshold] = -1

sol_2norm_bin = np.zeros(sol_2norm_min.shape)
sol_2norm_bin[sol_2norm_min >= threshold] = 1 # Your code here.
sol_2norm_bin[sol_2norm_min < threshold] = -1
# Out:
# Solution found after 117 iterations:
#     objective function f(sol) = 3.781302e+04
#     stopping criterion: RTOL
# Solution found after 2 iterations:
#     objective function f(sol) = 1.996828e+03
#     stopping criterion: RTOL

# %% [markdown]
# Plot, on your graph, the original `labels_bin` signal, as well as the solutions to the variational problems (both binarized and otherwise). Indicate on each plot the value of the relative error $\text{rel-err} = \frac{\|\text{labels_bin} - z\|_2}{\|\text{labels_bin}\|_2}$, where $z$ is the signal in the corresponding plot.

# %%
graph.plot_signal(labels_bin)
plt.title("Original Labels_bin " + 'Rel-err: {:.2E}'.format(relative_error(labels_bin)))

graph.plot_signal(sol_1norm_min)
plt.title("1−norm minimization " + 'Rel-err: {:.2E}'.format(relative_error(sol_1norm_min)))

graph.plot_signal(sol_2norm_min)
plt.title("2−norm minimization " + 'Rel-err: {:.2E}'.format(relative_error(sol_2norm_min)))

graph.plot_signal(sol_1norm_bin)
plt.title("Binarized 1−norm minimization " + 'Rel-err: {:.2E}'.format(relative_error(sol_1norm_bin)))

graph.plot_signal(sol_2norm_bin)
plt.title("Binarized 2−norm minimization " + 'Rel-err: {:.2E}'.format(relative_error(sol_2norm_bin)))
plt.show()
plt.close()

# %% [markdown]
# ### Question 16
#
# Now that you have got a feeling for the sort of solutions that the transductive learning problems studied can give, we will see what is the effect of the number of measurements on the accuracy of both $p-$norm minimization problems.
#
# Towards this goal, you will write a `phase_transition()` function. This function will basically go over all the procedures that you have implemented in this section, but for varying numbers of measurements and thresholding values. It will also compute the relative error, $\text{rel-err},$ of the solutions and average them over a number of trials.
#
# The output of the `phase_transition()` function has to be a matrix with `len(mn_ratios)` columns and `len(thresholds)` rows. Each pixel $(i,j)$ in the output matrix has to contain the average, over `n_trials` trials, of the relative error $\text{rel-err}$ in the binarized (with threshold `thresholds[i]`) solution given by `graph_pnorm_interpolation()` from observing an `mn_ratios[j]` fraction of nodes. The randomness comes from a different choice of mask `w` at each trial, hence the averaging.
#
# The interest of this phase transition matrix is to assess what level of recovery error one could expect for a certain fraction of measurements and a certain threshold level.

# %%
def phase_transition(mn_ratios, thresholds, n_trials, labels, p):
    ## Initialization
    pt_matrix = np.zeros((len(thresholds),len(mn_ratios)))
    np.random.seed(5)
    
    for column_ind, mn_ratio in enumerate(mn_ratios):
        m = int(mn_ratio * n_nodes)

        for row_ind, threshold in enumerate(thresholds):
            global labels_bin
            labels_bin = np.empty((len(labels),))
            labels_bin[labels<threshold] = -1 
            labels_bin[labels>=threshold] = 1 
            
            for _ in range(n_trials):
                global w
                w = np.zeros((n_nodes,))
                w[np.random.choice(n_nodes, m, replace=False)] = 1
                sol_norm = graph_pnorm_interpolation(gradient, P, x0=np.random.randn(n_nodes), p=p)
                sol_norm[sol_norm<threshold] = -1 
                sol_norm[sol_norm>=threshold] = 1
                pt_matrix[row_ind,column_ind] = pt_matrix[row_ind,column_ind] + relative_error(sol_norm)

    # Aggregate.
    pt_matrix = pt_matrix/n_trials
    return pt_matrix

# %% [markdown]
# ### Question 17
#
# Pick 5 "m/n" ratios in $(0, 1)$ and 5 threshold levels in $(-1, 1)$ and run the `phase_transition()` function with `n_trials` = 20, for both $p = 1$ and $p = 2$.

# %%
mn_ratios = [0.2,0.4,0.6,0.7,0.8]# Your code here.

thresholds = [-0.5, -0.25, 0, 0.25, 0.5]# Your code here.

n_trials = 20

pt_matrix_1norm = phase_transition(mn_ratios, thresholds, n_trials, labels_bin, p=1)# Your code here.

pt_matrix_2norm = phase_transition(mn_ratios, thresholds, n_trials, labels_bin, p=2)# Your code here.
# Out:
# Solution found after 117 iterations:
#     objective function f(sol) = 3.944934e+04
#     stopping criterion: RTOL
# Solution found after 117 iterations:
#     objective function f(sol) = 3.858461e+04
#     stopping criterion: RTOL
# Solution found after 117 iterations:
#     objective function f(sol) = 3.817065e+04
#     stopping criterion: RTOL
# Solution found after 117 iterations:
#     objective function f(sol) = 3.900760e+04
#     stopping criterion: RTOL
# Solution found after 117 iterations:
#     objective function f(sol) = 3.863588e+04
#     stopping criterion: RTOL
# Solution found after 117 iterations:
#     objective function f(sol) = 3.829173e+04
#     stopping criterion: RTOL
# Solution found after 117 iterations:
#     objective function f(sol) = 3.860763e+04
#     stopping criterion: RTOL
# Solution found after 117 iterations:
#     objective function f(sol) = 3.859320e+04
#     stopping criterion: RTOL
# Solution found after 117 iterations:
#     objective function f(sol) = 3.894855e+04
#     stopping criterion: RTOL
# Solution found after 117 iterations:
#     objective function f(sol) = 3.788679e+04
#     stopping criterion: RTOL
# Solution found after 117 iterations:
#     objective function f(sol) = 3.796224e+04
#     stopping criterion: RTOL
# Solution found after 117 iterations:
#     objective function f(sol) = 3.807815e+04
#     stopping criterion: RTOL
# Solution found after 117 iterations:
#     objective function f(sol) = 3.905534e+04
#     stopping criterion: RTOL
# Solution found after 117 iterations:
#     objective function f(sol) = 3.972743e+04
#     stopping criterion: RTOL
# Solution found after 117 iterations:
#     objective function f(sol) = 3.778451e+04
#     stopping criterion: RTOL
# Solution found after 117 iterations:
#     objective function f(sol) = 3.890120e+04
#     stopping criterion: RTOL
# Solution found after 117 iterations:
#     objective function f(sol) = 3.954928e+04
#     stopping criterion: RTOL
# Solution found after 117 iterations:
#     objective function f(sol) = 3.876831e+04
#     stopping criterion: RTOL
# Solution found after 117 iterations:
#     objective function f(sol) = 3.859527e+04
#     stopping criterion: RTOL
# Solution found after 117 iterations:
#     objective function f(sol) = 3.785895e+04
#     stopping criterion: RTOL
# Solution found after 117 iterations:
#     objective function f(sol) = 3.833917e+04
#     stopping criterion: RTOL
# Solution found after 117 iterations:
#     objective function f(sol) = 3.760541e+04
#     stopping criterion: RTOL
# Solution found after 117 iterations:
#     objective function f(sol) = 3.817603e+04
#     stopping criterion: RTOL
# Solution found after 117 iterations:
#     objective function f(sol) = 3.859334e+04
#     stopping criterion: RTOL
# Solution found after 117 iterations:
#     objective function f(sol) = 3.802598e+04
#     stopping criterion: RTOL
# Solution found after 117 iterations:
#     objective function f(sol) = 3.896645e+04
#     stopping criterion: RTOL
# Solution found after 117 iterations:
#     objective function f(sol) = 3.861084e+04
#     stopping criterion: RTOL
# Solution found after 117 iterations:
#     objective function f(sol) = 3.780338e+04
#     stopping criterion: RTOL
# Solution found after 117 iterations:
#     objective function f(sol) = 3.774330e+04
#     stopping criterion: RTOL
# Solution found after 117 iterations:
#     objective function f(sol) = 3.851367e+04
#     stopping criterion: RTOL
# Solution found after 117 iterations:
#     objective function f(sol) = 3.787927e+04
#     stopping criterion: RTOL
# Solution found after 117 iterations:
#     objective function f(sol) = 3.896923e+04
#     stopping criterion: RTOL
# Solution found after 117 iterations:
#     objective function f(sol) = 3.907298e+04
#     stopping criterion: RTOL
# Solution found after 117 iterations:
#     objective function f(sol) = 3.799256e+04
#     stopping criterion: RTOL
# Solution found after 117 iterations:
#     objective function f(sol) = 3.901199e+04
#     stopping criterion: RTOL
# Solution found after 117 iterations:
#     objective function f(sol) = 3.858296e+04
#     stopping criterion: RTOL
# Solution found after 117 iterations:
#     objective function f(sol) = 3.802042e+04
#     stopping criterion: RTOL
# Solution found after 117 iterations:
#     objective function f(sol) = 3.809928e+04
#     stopping criterion: RTOL
# Solution found after 117 iterations:
#     objective function f(sol) = 3.787662e+04
#     stopping criterion: RTOL
# Solution found after 117 iterations:
#     objective function f(sol) = 3.920748e+04
#     stopping criterion: RTOL
# Solution found after 117 iterations:
#     objective function f(sol) = 3.946741e+04
#     stopping criterion: RTOL
# Solution found after 117 iterations:
#     objective function f(sol) = 3.844475e+04
#     stopping criterion: RTOL
# Solution found after 117 iterations:
#     objective function f(sol) = 3.906325e+04
#     stopping criterion: RTOL
# Solution found after 117 iterations:
#     objective function f(sol) = 3.848347e+04
#     stopping criterion: RTOL
# Solution found after 117 iterations:
#     objective function f(sol) = 3.826338e+04
#     stopping criterion: RTOL
# Solution found after 117 iterations:
#     objective function f(sol) = 3.903258e+04
#     stopping criterion: RTOL
# Solution found after 117 iterations:
#     objective function f(sol) = 3.858293e+04
#     stopping criterion: RTOL
# Solution found after 117 iterations:
#     objective function f(sol) = 3.845755e+04
#     stopping criterion: RTOL
# Solution found after 117 iterations:
#     objective function f(sol) = 3.869496e+04
#     stopping criterion: RTOL
# Solution found after 117 iterations:
#     objective function f(sol) = 3.910701e+04
#     stopping criterion: RTOL
# Solution found after 117 iterations:
#     objective function f(sol) = 3.864596e+04
#     stopping criterion: RTOL
# Solution found after 117 iterations:
#     objective function f(sol) = 3.806918e+04
#     stopping criterion: RTOL
# Solution found after 117 iterations:
#     objective function f(sol) = 3.787868e+04
#     stopping criterion: RTOL
# Solution found after 117 iterations:
#     objective function f(sol) = 3.854709e+04
#     stopping criterion: RTOL
# Solution found after 117 iterations:
#     objective function f(sol) = 3.719591e+04
#     stopping criterion: RTOL
# Solution found after 1 iterations:
#     objective function f(sol) = 2.901415e+04
#     stopping criterion: RTOL
# Solution found after 117 iterations:
#     objective function f(sol) = 3.917778e+04
#     stopping criterion: RTOL
# Solution found after 117 iterations:
#     objective function f(sol) = 3.809296e+04
#     stopping criterion: RTOL
# Solution found after 117 iterations:
#     objective function f(sol) = 3.659101e+04
#     stopping criterion: RTOL
# Solution found after 117 iterations:
#     objective function f(sol) = 3.850082e+04
#     stopping criterion: RTOL
# Solution found after 117 iterations:
#     objective function f(sol) = 3.818788e+04
#     stopping criterion: RTOL
# Solution found after 117 iterations:
#     objective function f(sol) = 3.869071e+04
#     stopping criterion: RTOL
# Solution found after 117 iterations:
#     objective function f(sol) = 3.821178e+04
#     stopping criterion: RTOL
# Solution found after 117 iterations:
#     objective function f(sol) = 3.866113e+04
#     stopping criterion: RTOL
# Solution found after 117 iterations:
#     objective function f(sol) = 3.852611e+04
#     stopping criterion: RTOL
# Solution found after 117 iterations:
#     objective function f(sol) = 3.846727e+04
#     stopping criterion: RTOL
# Solution found after 117 iterations:
#     objective function f(sol) = 3.854386e+04
#     stopping criterion: RTOL
# Solution found after 117 iterations:
#     objective function f(sol) = 3.858427e+04
#     stopping criterion: RTOL
# Solution found after 117 iterations:
#     objective function f(sol) = 3.785681e+04
#     stopping criterion: RTOL
# Solution found after 117 iterations:
#     objective function f(sol) = 3.928130e+04
#     stopping criterion: RTOL
# Solution found after 117 iterations:
#     objective function f(sol) = 3.942032e+04
#     stopping criterion: RTOL
# Solution found after 117 iterations:
#     objective function f(sol) = 3.876212e+04
#     stopping criterion: RTOL
# Solution found after 117 iterations:
#     objective function f(sol) = 3.855134e+04
#     stopping criterion: RTOL
# Solution found after 117 iterations:
#     objective function f(sol) = 3.934435e+04
#     stopping criterion: RTOL
# Solution found after 117 iterations:
#     objective function f(sol) = 3.806454e+04
#     stopping criterion: RTOL
# Solution found after 117 iterations:
#     objective function f(sol) = 3.860061e+04
#     stopping criterion: RTOL
# Solution found after 117 iterations:
#     objective function f(sol) = 3.785147e+04
#     stopping criterion: RTOL
# Solution found after 117 iterations:
#     objective function f(sol) = 3.962390e+04
#     stopping criterion: RTOL
# Solution found after 117 iterations:
#     objective function f(sol) = 3.829282e+04
#     stopping criterion: RTOL
# Solution found after 117 iterations:
#     objective function f(sol) = 3.785634e+04
#     stopping criterion: RTOL
# Solution found after 117 iterations:
#     objective function f(sol) = 3.781164e+04
#     stopping criterion: RTOL
# Solution found after 117 iterations:
#     objective function f(sol) = 3.866026e+04
#     stopping criterion: RTOL
# Solution found after 117 iterations:
#     objective function f(sol) = 3.875117e+04
#     stopping criterion: RTOL
# Solution found after 117 iterations:
#     objective function f(sol) = 3.857775e+04
#     stopping criterion: RTOL
# Solution found after 117 iterations:
#     objective function f(sol) = 3.904597e+04
#     stopping criterion: RTOL
# Solution found after 117 iterations:
#     objective function f(sol) = 3.768304e+04
#     stopping criterion: RTOL
# Solution found after 117 iterations:
#     objective function f(sol) = 3.750554e+04
#     stopping criterion: RTOL
# Solution found after 117 iterations:
#     objective function f(sol) = 3.910724e+04
#     stopping criterion: RTOL
# Solution found after 117 iterations:
#     objective function f(sol) = 3.823755e+04
#     stopping criterion: RTOL
# Solution found after 117 iterations:
#     objective function f(sol) = 3.929738e+04
#     stopping criterion: RTOL
# Solution found after 117 iterations:
#     objective function f(sol) = 3.820475e+04
#     stopping criterion: RTOL
# Solution found after 117 iterations:
#     objective function f(sol) = 3.899966e+04
#     stopping criterion: RTOL
# Solution found after 117 iterations:
#     objective function f(sol) = 3.815751e+04
#     stopping criterion: RTOL
# Solution found after 117 iterations:
#     objective function f(sol) = 3.937021e+04
#     stopping criterion: RTOL
# Solution found after 117 iterations:
#     objective function f(sol) = 3.833997e+04
#     stopping criterion: RTOL
# Solution found after 117 iterations:
#     objective function f(sol) = 3.984827e+04
#     stopping criterion: RTOL
# Solution found after 1 iterations:
#     objective function f(sol) = 2.912186e+04
#     stopping criterion: RTOL
# Solution found after 117 iterations:
#     objective function f(sol) = 3.881968e+04
#     stopping criterion: RTOL
# Solution found after 117 iterations:
#     objective function f(sol) = 3.793780e+04
#     stopping criterion: RTOL
# Solution found after 117 iterations:
#     objective function f(sol) = 3.853473e+04
#     stopping criterion: RTOL
# Solution found after 117 iterations:
#     objective function f(sol) = 3.498303e+04
#     stopping criterion: RTOL
# Solution found after 117 iterations:
#     objective function f(sol) = 3.569737e+04
#     stopping criterion: RTOL
# Solution found after 117 iterations:
#     objective function f(sol) = 3.468776e+04
#     stopping criterion: RTOL
# Solution found after 117 iterations:
#     objective function f(sol) = 3.523341e+04
#     stopping criterion: RTOL
# Solution found after 117 iterations:
#     objective function f(sol) = 3.524068e+04
#     stopping criterion: RTOL
# Solution found after 117 iterations:
#     objective function f(sol) = 3.489576e+04
#     stopping criterion: RTOL
# Solution found after 117 iterations:
#     objective function f(sol) = 3.540889e+04
#     stopping criterion: RTOL
# Solution found after 116 iterations:
#     objective function f(sol) = 3.432727e+04
#     stopping criterion: RTOL
# Solution found after 117 iterations:
#     objective function f(sol) = 3.530790e+04
#     stopping criterion: RTOL
# Solution found after 117 iterations:
#     objective function f(sol) = 3.615441e+04
#     stopping criterion: RTOL
# Solution found after 117 iterations:
#     objective function f(sol) = 3.587491e+04
#     stopping criterion: RTOL
# Solution found after 117 iterations:
#     objective function f(sol) = 3.531894e+04
#     stopping criterion: RTOL
# Solution found after 117 iterations:
#     objective function f(sol) = 3.571968e+04
#     stopping criterion: RTOL
# Solution found after 117 iterations:
#     objective function f(sol) = 3.594611e+04
#     stopping criterion: RTOL
# Solution found after 117 iterations:
#     objective function f(sol) = 3.583047e+04
#     stopping criterion: RTOL
# Solution found after 117 iterations:
#     objective function f(sol) = 3.454785e+04
#     stopping criterion: RTOL
# Solution found after 116 iterations:
#     objective function f(sol) = 3.561618e+04
#     stopping criterion: RTOL
# Solution found after 117 iterations:
#     objective function f(sol) = 3.494197e+04
#     stopping criterion: RTOL
# Solution found after 117 iterations:
#     objective function f(sol) = 3.584442e+04
#     stopping criterion: RTOL
# Solution found after 117 iterations:
#     objective function f(sol) = 3.520686e+04
#     stopping criterion: RTOL
# Solution found after 117 iterations:
#     objective function f(sol) = 3.561254e+04
#     stopping criterion: RTOL
# Solution found after 117 iterations:
#     objective function f(sol) = 3.486759e+04
#     stopping criterion: RTOL
# Solution found after 116 iterations:
#     objective function f(sol) = 3.463214e+04
#     stopping criterion: RTOL
# Solution found after 117 iterations:
#     objective function f(sol) = 3.487552e+04
#     stopping criterion: RTOL
# Solution found after 117 iterations:
#     objective function f(sol) = 3.482705e+04
#     stopping criterion: RTOL
# Solution found after 117 iterations:
#     objective function f(sol) = 3.635017e+04
#     stopping criterion: RTOL
# Solution found after 117 iterations:
#     objective function f(sol) = 3.547288e+04
#     stopping criterion: RTOL
# Solution found after 117 iterations:
#     objective function f(sol) = 3.529977e+04
#     stopping criterion: RTOL
# Solution found after 117 iterations:
#     objective function f(sol) = 3.615365e+04
#     stopping criterion: RTOL
# Solution found after 117 iterations:
#     objective function f(sol) = 3.557372e+04
#     stopping criterion: RTOL
# Solution found after 117 iterations:
#     objective function f(sol) = 3.513442e+04
#     stopping criterion: RTOL
# Solution found after 117 iterations:
#     objective function f(sol) = 3.500199e+04
#     stopping criterion: RTOL
# Solution found after 117 iterations:
#     objective function f(sol) = 3.553912e+04
#     stopping criterion: RTOL
# Solution found after 117 iterations:
#     objective function f(sol) = 3.539112e+04
#     stopping criterion: RTOL
# Solution found after 117 iterations:
#     objective function f(sol) = 3.586733e+04
#     stopping criterion: RTOL
# Solution found after 117 iterations:
#     objective function f(sol) = 3.563287e+04
#     stopping criterion: RTOL
# Solution found after 117 iterations:
#     objective function f(sol) = 3.545130e+04
#     stopping criterion: RTOL
# Solution found after 117 iterations:
#     objective function f(sol) = 3.601610e+04
#     stopping criterion: RTOL
# Solution found after 117 iterations:
#     objective function f(sol) = 3.536393e+04
#     stopping criterion: RTOL
# Solution found after 117 iterations:
#     objective function f(sol) = 3.540793e+04
#     stopping criterion: RTOL
# Solution found after 117 iterations:
#     objective function f(sol) = 3.442404e+04
#     stopping criterion: RTOL
# Solution found after 117 iterations:
#     objective function f(sol) = 3.558905e+04
#     stopping criterion: RTOL
# Solution found after 116 iterations:
#     objective function f(sol) = 3.457957e+04
#     stopping criterion: RTOL
# Solution found after 117 iterations:
#     objective function f(sol) = 3.534598e+04
#     stopping criterion: RTOL
# Solution found after 117 iterations:
#     objective function f(sol) = 3.637583e+04
#     stopping criterion: RTOL
# Solution found after 117 iterations:
#     objective function f(sol) = 3.552274e+04
#     stopping criterion: RTOL
# Solution found after 117 iterations:
#     objective function f(sol) = 3.488991e+04
#     stopping criterion: RTOL
# Solution found after 117 iterations:
#     objective function f(sol) = 3.491372e+04
#     stopping criterion: RTOL
# Solution found after 117 iterations:
#     objective function f(sol) = 3.526350e+04
#     stopping criterion: RTOL
# Solution found after 117 iterations:
#     objective function f(sol) = 3.518982e+04
#     stopping criterion: RTOL
# Solution found after 117 iterations:
#     objective function f(sol) = 3.507674e+04
#     stopping criterion: RTOL
# Solution found after 116 iterations:
#     objective function f(sol) = 3.496204e+04
#     stopping criterion: RTOL
# Solution found after 117 iterations:
#     objective function f(sol) = 3.548026e+04
#     stopping criterion: RTOL
# Solution found after 116 iterations:
#     objective function f(sol) = 3.484605e+04
#     stopping criterion: RTOL
# Solution found after 116 iterations:
#     objective function f(sol) = 3.513540e+04
#     stopping criterion: RTOL
# Solution found after 117 iterations:
#     objective function f(sol) = 3.523969e+04
#     stopping criterion: RTOL
# Solution found after 116 iterations:
#     objective function f(sol) = 3.478102e+04
#     stopping criterion: RTOL
# Solution found after 117 iterations:
#     objective function f(sol) = 3.603730e+04
#     stopping criterion: RTOL
# Solution found after 117 iterations:
#     objective function f(sol) = 3.525273e+04
#     stopping criterion: RTOL
# Solution found after 117 iterations:
#     objective function f(sol) = 3.481187e+04
#     stopping criterion: RTOL
# Solution found after 117 iterations:
#     objective function f(sol) = 3.480716e+04
#     stopping criterion: RTOL
# Solution found after 117 iterations:
#     objective function f(sol) = 3.494875e+04
#     stopping criterion: RTOL
# Solution found after 117 iterations:
#     objective function f(sol) = 3.546564e+04
#     stopping criterion: RTOL
# Solution found after 116 iterations:
#     objective function f(sol) = 3.496550e+04
#     stopping criterion: RTOL
# Solution found after 116 iterations:
#     objective function f(sol) = 3.485944e+04
#     stopping criterion: RTOL
# Solution found after 117 iterations:
#     objective function f(sol) = 3.502152e+04
#     stopping criterion: RTOL
# Solution found after 117 iterations:
#     objective function f(sol) = 3.585845e+04
#     stopping criterion: RTOL
# Solution found after 117 iterations:
#     objective function f(sol) = 3.468214e+04
#     stopping criterion: RTOL
# Solution found after 117 iterations:
#     objective function f(sol) = 3.480019e+04
#     stopping criterion: RTOL
# Solution found after 116 iterations:
#     objective function f(sol) = 3.550521e+04
#     stopping criterion: RTOL
# Solution found after 117 iterations:
#     objective function f(sol) = 3.492172e+04
#     stopping criterion: RTOL
# Solution found after 117 iterations:
#     objective function f(sol) = 3.534441e+04
#     stopping criterion: RTOL
# Solution found after 117 iterations:
#     objective function f(sol) = 3.481601e+04
#     stopping criterion: RTOL
# Solution found after 117 iterations:
#     objective function f(sol) = 3.597749e+04
#     stopping criterion: RTOL
# Solution found after 117 iterations:
#     objective function f(sol) = 3.586177e+04
#     stopping criterion: RTOL
# Solution found after 117 iterations:
#     objective function f(sol) = 3.568797e+04
#     stopping criterion: RTOL
# Solution found after 117 iterations:
#     objective function f(sol) = 3.545093e+04
#     stopping criterion: RTOL
# Solution found after 116 iterations:
#     objective function f(sol) = 3.494703e+04
#     stopping criterion: RTOL
# Solution found after 117 iterations:
#     objective function f(sol) = 3.497018e+04
#     stopping criterion: RTOL
# Solution found after 117 iterations:
#     objective function f(sol) = 3.557898e+04
#     stopping criterion: RTOL
# Solution found after 117 iterations:
#     objective function f(sol) = 3.558231e+04
#     stopping criterion: RTOL
# Solution found after 117 iterations:
#     objective function f(sol) = 3.558249e+04
#     stopping criterion: RTOL
# Solution found after 116 iterations:
#     objective function f(sol) = 3.424012e+04
#     stopping criterion: RTOL
# Solution found after 117 iterations:
#     objective function f(sol) = 3.564220e+04
#     stopping criterion: RTOL
# Solution found after 117 iterations:
#     objective function f(sol) = 3.468161e+04
#     stopping criterion: RTOL
# Solution found after 117 iterations:
#     objective function f(sol) = 3.494296e+04
#     stopping criterion: RTOL
# Solution found after 117 iterations:
#     objective function f(sol) = 3.549360e+04
#     stopping criterion: RTOL
# Solution found after 117 iterations:
#     objective function f(sol) = 3.629351e+04
#     stopping criterion: RTOL
# Solution found after 117 iterations:
#     objective function f(sol) = 3.595480e+04
#     stopping criterion: RTOL
# Solution found after 116 iterations:
#     objective function f(sol) = 3.533220e+04
#     stopping criterion: RTOL
# Solution found after 117 iterations:
#     objective function f(sol) = 3.478056e+04
#     stopping criterion: RTOL
# Solution found after 117 iterations:
#     objective function f(sol) = 3.527694e+04
#     stopping criterion: RTOL
# Solution found after 117 iterations:
#     objective function f(sol) = 3.511851e+04
#     stopping criterion: RTOL
# Solution found after 117 iterations:
#     objective function f(sol) = 3.626057e+04
#     stopping criterion: RTOL
# Solution found after 117 iterations:
#     objective function f(sol) = 3.555058e+04
#     stopping criterion: RTOL
# Solution found after 116 iterations:
#     objective function f(sol) = 3.488500e+04
#     stopping criterion: RTOL
# Solution found after 117 iterations:
#     objective function f(sol) = 3.523288e+04
#     stopping criterion: RTOL
# Solution found after 117 iterations:
#     objective function f(sol) = 3.468968e+04
#     stopping criterion: RTOL
# Solution found after 117 iterations:
#     objective function f(sol) = 3.534337e+04
#     stopping criterion: RTOL
# Solution found after 117 iterations:
#     objective function f(sol) = 3.546269e+04
#     stopping criterion: RTOL
# Solution found after 116 iterations:
#     objective function f(sol) = 3.150712e+04
#     stopping criterion: RTOL
# Solution found after 116 iterations:
#     objective function f(sol) = 3.107410e+04
#     stopping criterion: RTOL
# Solution found after 117 iterations:
#     objective function f(sol) = 3.189360e+04
#     stopping criterion: RTOL
# Solution found after 116 iterations:
#     objective function f(sol) = 3.168402e+04
#     stopping criterion: RTOL
# Solution found after 116 iterations:
#     objective function f(sol) = 3.149093e+04
#     stopping criterion: RTOL
# Solution found after 116 iterations:
#     objective function f(sol) = 3.145397e+04
#     stopping criterion: RTOL
# Solution found after 116 iterations:
#     objective function f(sol) = 3.128918e+04
#     stopping criterion: RTOL
# Solution found after 116 iterations:
#     objective function f(sol) = 3.112220e+04
#     stopping criterion: RTOL
# Solution found after 116 iterations:
#     objective function f(sol) = 3.164855e+04
#     stopping criterion: RTOL
# Solution found after 116 iterations:
#     objective function f(sol) = 3.161160e+04
#     stopping criterion: RTOL
# Solution found after 116 iterations:
#     objective function f(sol) = 3.176620e+04
#     stopping criterion: RTOL
# Solution found after 116 iterations:
#     objective function f(sol) = 3.172514e+04
#     stopping criterion: RTOL
# Solution found after 116 iterations:
#     objective function f(sol) = 3.118386e+04
#     stopping criterion: RTOL
# Solution found after 116 iterations:
#     objective function f(sol) = 3.202807e+04
#     stopping criterion: RTOL
# Solution found after 116 iterations:
#     objective function f(sol) = 3.120379e+04
#     stopping criterion: RTOL
# Solution found after 116 iterations:
#     objective function f(sol) = 3.174922e+04
#     stopping criterion: RTOL
# Solution found after 116 iterations:
#     objective function f(sol) = 3.140031e+04
#     stopping criterion: RTOL
# Solution found after 116 iterations:
#     objective function f(sol) = 3.082897e+04
#     stopping criterion: RTOL
# Solution found after 116 iterations:
#     objective function f(sol) = 3.211195e+04
#     stopping criterion: RTOL
# Solution found after 115 iterations:
#     objective function f(sol) = 3.102021e+04
#     stopping criterion: RTOL
# Solution found after 116 iterations:
#     objective function f(sol) = 3.122816e+04
#     stopping criterion: RTOL
# Solution found after 116 iterations:
#     objective function f(sol) = 3.102552e+04
#     stopping criterion: RTOL
# Solution found after 116 iterations:
#     objective function f(sol) = 3.150953e+04
#     stopping criterion: RTOL
# Solution found after 116 iterations:
#     objective function f(sol) = 3.150448e+04
#     stopping criterion: RTOL
# Solution found after 116 iterations:
#     objective function f(sol) = 3.144102e+04
#     stopping criterion: RTOL
# Solution found after 116 iterations:
#     objective function f(sol) = 3.100285e+04
#     stopping criterion: RTOL
# Solution found after 116 iterations:
#     objective function f(sol) = 3.183999e+04
#     stopping criterion: RTOL
# Solution found after 116 iterations:
#     objective function f(sol) = 3.173075e+04
#     stopping criterion: RTOL
# Solution found after 116 iterations:
#     objective function f(sol) = 3.209665e+04
#     stopping criterion: RTOL
# Solution found after 116 iterations:
#     objective function f(sol) = 3.162381e+04
#     stopping criterion: RTOL
# Solution found after 116 iterations:
#     objective function f(sol) = 3.171782e+04
#     stopping criterion: RTOL
# Solution found after 116 iterations:
#     objective function f(sol) = 3.192474e+04
#     stopping criterion: RTOL
# Solution found after 116 iterations:
#     objective function f(sol) = 3.027252e+04
#     stopping criterion: RTOL
# Solution found after 116 iterations:
#     objective function f(sol) = 3.151853e+04
#     stopping criterion: RTOL
# Solution found after 116 iterations:
#     objective function f(sol) = 3.127951e+04
#     stopping criterion: RTOL
# Solution found after 116 iterations:
#     objective function f(sol) = 3.072909e+04
#     stopping criterion: RTOL
# Solution found after 116 iterations:
#     objective function f(sol) = 3.173081e+04
#     stopping criterion: RTOL
# Solution found after 116 iterations:
#     objective function f(sol) = 3.126971e+04
#     stopping criterion: RTOL
# Solution found after 116 iterations:
#     objective function f(sol) = 3.142836e+04
#     stopping criterion: RTOL
# Solution found after 116 iterations:
#     objective function f(sol) = 3.213250e+04
#     stopping criterion: RTOL
# Solution found after 116 iterations:
#     objective function f(sol) = 3.110636e+04
#     stopping criterion: RTOL
# Solution found after 116 iterations:
#     objective function f(sol) = 3.177538e+04
#     stopping criterion: RTOL
# Solution found after 116 iterations:
#     objective function f(sol) = 3.111354e+04
#     stopping criterion: RTOL
# Solution found after 116 iterations:
#     objective function f(sol) = 3.110418e+04
#     stopping criterion: RTOL
# Solution found after 40 iterations:
#     objective function f(sol) = 2.046671e+04
#     stopping criterion: RTOL
# Solution found after 116 iterations:
#     objective function f(sol) = 3.173913e+04
#     stopping criterion: RTOL
# Solution found after 116 iterations:
#     objective function f(sol) = 3.136529e+04
#     stopping criterion: RTOL
# Solution found after 116 iterations:
#     objective function f(sol) = 3.163746e+04
#     stopping criterion: RTOL
# Solution found after 116 iterations:
#     objective function f(sol) = 3.202784e+04
#     stopping criterion: RTOL
# Solution found after 116 iterations:
#     objective function f(sol) = 3.114758e+04
#     stopping criterion: RTOL
# Solution found after 116 iterations:
#     objective function f(sol) = 3.103948e+04
#     stopping criterion: RTOL
# Solution found after 116 iterations:
#     objective function f(sol) = 3.088912e+04
#     stopping criterion: RTOL
# Solution found after 116 iterations:
#     objective function f(sol) = 3.150688e+04
#     stopping criterion: RTOL
# Solution found after 40 iterations:
#     objective function f(sol) = 2.019959e+04
#     stopping criterion: RTOL
# Solution found after 116 iterations:
#     objective function f(sol) = 3.134336e+04
#     stopping criterion: RTOL
# Solution found after 116 iterations:
#     objective function f(sol) = 3.161466e+04
#     stopping criterion: RTOL
# Solution found after 116 iterations:
#     objective function f(sol) = 3.114819e+04
#     stopping criterion: RTOL
# Solution found after 116 iterations:
#     objective function f(sol) = 3.165527e+04
#     stopping criterion: RTOL
# Solution found after 116 iterations:
#     objective function f(sol) = 3.152363e+04
#     stopping criterion: RTOL
# Solution found after 116 iterations:
#     objective function f(sol) = 3.138775e+04
#     stopping criterion: RTOL
# Solution found after 116 iterations:
#     objective function f(sol) = 3.075580e+04
#     stopping criterion: RTOL
# Solution found after 116 iterations:
#     objective function f(sol) = 3.195631e+04
#     stopping criterion: RTOL
# Solution found after 116 iterations:
#     objective function f(sol) = 3.066098e+04
#     stopping criterion: RTOL
# Solution found after 116 iterations:
#     objective function f(sol) = 3.125468e+04
#     stopping criterion: RTOL
# Solution found after 116 iterations:
#     objective function f(sol) = 3.115711e+04
#     stopping criterion: RTOL
# Solution found after 117 iterations:
#     objective function f(sol) = 3.137413e+04
#     stopping criterion: RTOL
# Solution found after 116 iterations:
#     objective function f(sol) = 3.266374e+04
#     stopping criterion: RTOL
# Solution found after 116 iterations:
#     objective function f(sol) = 3.155903e+04
#     stopping criterion: RTOL
# Solution found after 116 iterations:
#     objective function f(sol) = 3.229206e+04
#     stopping criterion: RTOL
# Solution found after 116 iterations:
#     objective function f(sol) = 3.153408e+04
#     stopping criterion: RTOL
# Solution found after 116 iterations:
#     objective function f(sol) = 3.104406e+04
#     stopping criterion: RTOL
# Solution found after 116 iterations:
#     objective function f(sol) = 3.216383e+04
#     stopping criterion: RTOL
# Solution found after 116 iterations:
#     objective function f(sol) = 3.120580e+04
#     stopping criterion: RTOL
# Solution found after 116 iterations:
#     objective function f(sol) = 3.215972e+04
#     stopping criterion: RTOL
# Solution found after 116 iterations:
#     objective function f(sol) = 3.104649e+04
#     stopping criterion: RTOL
# Solution found after 116 iterations:
#     objective function f(sol) = 3.134970e+04
#     stopping criterion: RTOL
# Solution found after 116 iterations:
#     objective function f(sol) = 3.206331e+04
#     stopping criterion: RTOL
# Solution found after 116 iterations:
#     objective function f(sol) = 3.202207e+04
#     stopping criterion: RTOL
# Solution found after 116 iterations:
#     objective function f(sol) = 3.182244e+04
#     stopping criterion: RTOL
# Solution found after 116 iterations:
#     objective function f(sol) = 3.144493e+04
#     stopping criterion: RTOL
# Solution found after 116 iterations:
#     objective function f(sol) = 3.135181e+04
#     stopping criterion: RTOL
# Solution found after 116 iterations:
#     objective function f(sol) = 3.200991e+04
#     stopping criterion: RTOL
# Solution found after 116 iterations:
#     objective function f(sol) = 3.159757e+04
#     stopping criterion: RTOL
# Solution found after 115 iterations:
#     objective function f(sol) = 3.063048e+04
#     stopping criterion: RTOL
# Solution found after 116 iterations:
#     objective function f(sol) = 3.144762e+04
#     stopping criterion: RTOL
# Solution found after 116 iterations:
#     objective function f(sol) = 3.161984e+04
#     stopping criterion: RTOL
# Solution found after 116 iterations:
#     objective function f(sol) = 3.239244e+04
#     stopping criterion: RTOL
# Solution found after 40 iterations:
#     objective function f(sol) = 2.034121e+04
#     stopping criterion: RTOL
# Solution found after 116 iterations:
#     objective function f(sol) = 3.186413e+04
#     stopping criterion: RTOL
# Solution found after 116 iterations:
#     objective function f(sol) = 3.170446e+04
#     stopping criterion: RTOL
# Solution found after 116 iterations:
#     objective function f(sol) = 3.143049e+04
#     stopping criterion: RTOL
# Solution found after 116 iterations:
#     objective function f(sol) = 3.130841e+04
#     stopping criterion: RTOL
# Solution found after 116 iterations:
#     objective function f(sol) = 3.126002e+04
#     stopping criterion: RTOL
# Solution found after 116 iterations:
#     objective function f(sol) = 3.068470e+04
#     stopping criterion: RTOL
# Solution found after 116 iterations:
#     objective function f(sol) = 3.181019e+04
#     stopping criterion: RTOL
# Solution found after 116 iterations:
#     objective function f(sol) = 3.164192e+04
#     stopping criterion: RTOL
# Solution found after 116 iterations:
#     objective function f(sol) = 3.114742e+04
#     stopping criterion: RTOL
# Solution found after 116 iterations:
#     objective function f(sol) = 3.127117e+04
#     stopping criterion: RTOL
# Solution found after 117 iterations:
#     objective function f(sol) = 3.209987e+04
#     stopping criterion: RTOL
# Solution found after 116 iterations:
#     objective function f(sol) = 3.161174e+04
#     stopping criterion: RTOL
# Solution found after 40 iterations:
#     objective function f(sol) = 2.160151e+04
#     stopping criterion: RTOL
# Solution found after 40 iterations:
#     objective function f(sol) = 2.148308e+04
#     stopping criterion: RTOL
# Solution found after 41 iterations:
#     objective function f(sol) = 2.170569e+04
#     stopping criterion: RTOL
# Solution found after 41 iterations:
#     objective function f(sol) = 2.158288e+04
#     stopping criterion: RTOL
# Solution found after 41 iterations:
#     objective function f(sol) = 2.165846e+04
#     stopping criterion: RTOL
# Solution found after 41 iterations:
#     objective function f(sol) = 2.172310e+04
#     stopping criterion: RTOL
# Solution found after 41 iterations:
#     objective function f(sol) = 2.168961e+04
#     stopping criterion: RTOL
# Solution found after 40 iterations:
#     objective function f(sol) = 2.156066e+04
#     stopping criterion: RTOL
# Solution found after 41 iterations:
#     objective function f(sol) = 2.177363e+04
#     stopping criterion: RTOL
# Solution found after 41 iterations:
#     objective function f(sol) = 2.165766e+04
#     stopping criterion: RTOL
# Solution found after 41 iterations:
#     objective function f(sol) = 2.163943e+04
#     stopping criterion: RTOL
# Solution found after 41 iterations:
#     objective function f(sol) = 2.179136e+04
#     stopping criterion: RTOL
# Solution found after 40 iterations:
#     objective function f(sol) = 2.166489e+04
#     stopping criterion: RTOL
# Solution found after 41 iterations:
#     objective function f(sol) = 2.142188e+04
#     stopping criterion: RTOL
# Solution found after 40 iterations:
#     objective function f(sol) = 2.151405e+04
#     stopping criterion: RTOL
# Solution found after 41 iterations:
#     objective function f(sol) = 2.153961e+04
#     stopping criterion: RTOL
# Solution found after 40 iterations:
#     objective function f(sol) = 2.166458e+04
#     stopping criterion: RTOL
# Solution found after 41 iterations:
#     objective function f(sol) = 2.158701e+04
#     stopping criterion: RTOL
# Solution found after 40 iterations:
#     objective function f(sol) = 2.151681e+04
#     stopping criterion: RTOL
# Solution found after 40 iterations:
#     objective function f(sol) = 2.156651e+04
#     stopping criterion: RTOL
# Solution found after 40 iterations:
#     objective function f(sol) = 2.165057e+04
#     stopping criterion: RTOL
# Solution found after 40 iterations:
#     objective function f(sol) = 2.159139e+04
#     stopping criterion: RTOL
# Solution found after 40 iterations:
#     objective function f(sol) = 2.165942e+04
#     stopping criterion: RTOL
# Solution found after 40 iterations:
#     objective function f(sol) = 2.138631e+04
#     stopping criterion: RTOL
# Solution found after 40 iterations:
#     objective function f(sol) = 2.159916e+04
#     stopping criterion: RTOL
# Solution found after 40 iterations:
#     objective function f(sol) = 2.137938e+04
#     stopping criterion: RTOL
# Solution found after 40 iterations:
#     objective function f(sol) = 2.164241e+04
#     stopping criterion: RTOL
# Solution found after 41 iterations:
#     objective function f(sol) = 2.171940e+04
#     stopping criterion: RTOL
# Solution found after 40 iterations:
#     objective function f(sol) = 2.160551e+04
#     stopping criterion: RTOL
# Solution found after 40 iterations:
#     objective function f(sol) = 2.157557e+04
#     stopping criterion: RTOL
# Solution found after 41 iterations:
#     objective function f(sol) = 2.142910e+04
#     stopping criterion: RTOL
# Solution found after 40 iterations:
#     objective function f(sol) = 2.156518e+04
#     stopping criterion: RTOL
# Solution found after 40 iterations:
#     objective function f(sol) = 2.156708e+04
#     stopping criterion: RTOL
# Solution found after 40 iterations:
#     objective function f(sol) = 2.170708e+04
#     stopping criterion: RTOL
# Solution found after 40 iterations:
#     objective function f(sol) = 2.172135e+04
#     stopping criterion: RTOL
# Solution found after 40 iterations:
#     objective function f(sol) = 2.153270e+04
#     stopping criterion: RTOL
# Solution found after 41 iterations:
#     objective function f(sol) = 2.165692e+04
#     stopping criterion: RTOL
# Solution found after 41 iterations:
#     objective function f(sol) = 2.161892e+04
#     stopping criterion: RTOL
# Solution found after 41 iterations:
#     objective function f(sol) = 2.157506e+04
#     stopping criterion: RTOL
# Solution found after 41 iterations:
#     objective function f(sol) = 2.146958e+04
#     stopping criterion: RTOL
# Solution found after 41 iterations:
#     objective function f(sol) = 2.142828e+04
#     stopping criterion: RTOL
# Solution found after 41 iterations:
#     objective function f(sol) = 2.168745e+04
#     stopping criterion: RTOL
# Solution found after 40 iterations:
#     objective function f(sol) = 2.171213e+04
#     stopping criterion: RTOL
# Solution found after 41 iterations:
#     objective function f(sol) = 2.151166e+04
#     stopping criterion: RTOL
# Solution found after 40 iterations:
#     objective function f(sol) = 2.154040e+04
#     stopping criterion: RTOL
# Solution found after 41 iterations:
#     objective function f(sol) = 2.168780e+04
#     stopping criterion: RTOL
# Solution found after 40 iterations:
#     objective function f(sol) = 2.152942e+04
#     stopping criterion: RTOL
# Solution found after 40 iterations:
#     objective function f(sol) = 2.175931e+04
#     stopping criterion: RTOL
# Solution found after 40 iterations:
#     objective function f(sol) = 2.162590e+04
#     stopping criterion: RTOL
# Solution found after 40 iterations:
#     objective function f(sol) = 2.164114e+04
#     stopping criterion: RTOL
# Solution found after 40 iterations:
#     objective function f(sol) = 2.154812e+04
#     stopping criterion: RTOL
# Solution found after 41 iterations:
#     objective function f(sol) = 2.168199e+04
#     stopping criterion: RTOL
# Solution found after 41 iterations:
#     objective function f(sol) = 2.173920e+04
#     stopping criterion: RTOL
# Solution found after 41 iterations:
#     objective function f(sol) = 2.155458e+04
#     stopping criterion: RTOL
# Solution found after 40 iterations:
#     objective function f(sol) = 2.155111e+04
#     stopping criterion: RTOL
# Solution found after 40 iterations:
#     objective function f(sol) = 2.144772e+04
#     stopping criterion: RTOL
# Solution found after 41 iterations:
#     objective function f(sol) = 2.152391e+04
#     stopping criterion: RTOL
# Solution found after 40 iterations:
#     objective function f(sol) = 2.148447e+04
#     stopping criterion: RTOL
# Solution found after 40 iterations:
#     objective function f(sol) = 2.144002e+04
#     stopping criterion: RTOL
# Solution found after 40 iterations:
#     objective function f(sol) = 2.164784e+04
#     stopping criterion: RTOL
# Solution found after 40 iterations:
#     objective function f(sol) = 2.153672e+04
#     stopping criterion: RTOL
# Solution found after 40 iterations:
#     objective function f(sol) = 2.156423e+04
#     stopping criterion: RTOL
# Solution found after 41 iterations:
#     objective function f(sol) = 2.163014e+04
#     stopping criterion: RTOL
# Solution found after 40 iterations:
#     objective function f(sol) = 2.157385e+04
#     stopping criterion: RTOL
# Solution found after 40 iterations:
#     objective function f(sol) = 2.146323e+04
#     stopping criterion: RTOL
# Solution found after 40 iterations:
#     objective function f(sol) = 2.152335e+04
#     stopping criterion: RTOL
# Solution found after 40 iterations:
#     objective function f(sol) = 2.164482e+04
#     stopping criterion: RTOL
# Solution found after 40 iterations:
#     objective function f(sol) = 2.149356e+04
#     stopping criterion: RTOL
# Solution found after 40 iterations:
#     objective function f(sol) = 2.174789e+04
#     stopping criterion: RTOL
# Solution found after 40 iterations:
#     objective function f(sol) = 2.158238e+04
#     stopping criterion: RTOL
# Solution found after 41 iterations:
#     objective function f(sol) = 2.152613e+04
#     stopping criterion: RTOL
# Solution found after 40 iterations:
#     objective function f(sol) = 2.131058e+04
#     stopping criterion: RTOL
# Solution found after 40 iterations:
#     objective function f(sol) = 2.170426e+04
#     stopping criterion: RTOL
# Solution found after 40 iterations:
#     objective function f(sol) = 2.164480e+04
#     stopping criterion: RTOL
# Solution found after 40 iterations:
#     objective function f(sol) = 2.159677e+04
#     stopping criterion: RTOL
# Solution found after 41 iterations:
#     objective function f(sol) = 2.167315e+04
#     stopping criterion: RTOL
# Solution found after 41 iterations:
#     objective function f(sol) = 2.169120e+04
#     stopping criterion: RTOL
# Solution found after 40 iterations:
#     objective function f(sol) = 2.155736e+04
#     stopping criterion: RTOL
# Solution found after 40 iterations:
#     objective function f(sol) = 2.146394e+04
#     stopping criterion: RTOL
# Solution found after 40 iterations:
#     objective function f(sol) = 2.159339e+04
#     stopping criterion: RTOL
# Solution found after 40 iterations:
#     objective function f(sol) = 2.163337e+04
#     stopping criterion: RTOL
# Solution found after 40 iterations:
#     objective function f(sol) = 2.154261e+04
#     stopping criterion: RTOL
# Solution found after 41 iterations:
#     objective function f(sol) = 2.158655e+04
#     stopping criterion: RTOL
# Solution found after 41 iterations:
#     objective function f(sol) = 2.154366e+04
#     stopping criterion: RTOL
# Solution found after 40 iterations:
#     objective function f(sol) = 2.151629e+04
#     stopping criterion: RTOL
# Solution found after 41 iterations:
#     objective function f(sol) = 2.172725e+04
#     stopping criterion: RTOL
# Solution found after 40 iterations:
#     objective function f(sol) = 2.163782e+04
#     stopping criterion: RTOL
# Solution found after 40 iterations:
#     objective function f(sol) = 2.153656e+04
#     stopping criterion: RTOL
# Solution found after 40 iterations:
#     objective function f(sol) = 2.143061e+04
#     stopping criterion: RTOL
# Solution found after 41 iterations:
#     objective function f(sol) = 2.162124e+04
#     stopping criterion: RTOL
# Solution found after 40 iterations:
#     objective function f(sol) = 2.156868e+04
#     stopping criterion: RTOL
# Solution found after 40 iterations:
#     objective function f(sol) = 2.158947e+04
#     stopping criterion: RTOL
# Solution found after 40 iterations:
#     objective function f(sol) = 2.160970e+04
#     stopping criterion: RTOL
# Solution found after 41 iterations:
#     objective function f(sol) = 2.158616e+04
#     stopping criterion: RTOL
# Solution found after 41 iterations:
#     objective function f(sol) = 2.160588e+04
#     stopping criterion: RTOL
# Solution found after 41 iterations:
#     objective function f(sol) = 2.150995e+04
#     stopping criterion: RTOL
# Solution found after 41 iterations:
#     objective function f(sol) = 2.175096e+04
#     stopping criterion: RTOL
# Solution found after 40 iterations:
#     objective function f(sol) = 2.165272e+04
#     stopping criterion: RTOL
# Solution found after 41 iterations:
#     objective function f(sol) = 2.163016e+04
#     stopping criterion: RTOL
# Solution found after 40 iterations:
#     objective function f(sol) = 2.170407e+04
#     stopping criterion: RTOL
# Solution found after 40 iterations:
#     objective function f(sol) = 2.231803e+04
#     stopping criterion: RTOL
# Solution found after 39 iterations:
#     objective function f(sol) = 2.219010e+04
#     stopping criterion: RTOL
# Solution found after 40 iterations:
#     objective function f(sol) = 2.219246e+04
#     stopping criterion: RTOL
# Solution found after 40 iterations:
#     objective function f(sol) = 2.227408e+04
#     stopping criterion: RTOL
# Solution found after 40 iterations:
#     objective function f(sol) = 2.208602e+04
#     stopping criterion: RTOL
# Solution found after 39 iterations:
#     objective function f(sol) = 2.247971e+04
#     stopping criterion: RTOL
# Solution found after 40 iterations:
#     objective function f(sol) = 2.226241e+04
#     stopping criterion: RTOL
# Solution found after 40 iterations:
#     objective function f(sol) = 2.226187e+04
#     stopping criterion: RTOL
# Solution found after 40 iterations:
#     objective function f(sol) = 2.235973e+04
#     stopping criterion: RTOL
# Solution found after 40 iterations:
#     objective function f(sol) = 2.232730e+04
#     stopping criterion: RTOL
# Solution found after 40 iterations:
#     objective function f(sol) = 2.234980e+04
#     stopping criterion: RTOL
# Solution found after 40 iterations:
#     objective function f(sol) = 2.237924e+04
#     stopping criterion: RTOL
# Solution found after 40 iterations:
#     objective function f(sol) = 2.232254e+04
#     stopping criterion: RTOL
# Solution found after 40 iterations:
#     objective function f(sol) = 2.225817e+04
#     stopping criterion: RTOL
# Solution found after 39 iterations:
#     objective function f(sol) = 2.215855e+04
#     stopping criterion: RTOL
# Solution found after 40 iterations:
#     objective function f(sol) = 2.231908e+04
#     stopping criterion: RTOL
# Solution found after 40 iterations:
#     objective function f(sol) = 2.234768e+04
#     stopping criterion: RTOL
# Solution found after 39 iterations:
#     objective function f(sol) = 2.220637e+04
#     stopping criterion: RTOL
# Solution found after 40 iterations:
#     objective function f(sol) = 2.234037e+04
#     stopping criterion: RTOL
# Solution found after 40 iterations:
#     objective function f(sol) = 2.223494e+04
#     stopping criterion: RTOL
# Solution found after 40 iterations:
#     objective function f(sol) = 2.222942e+04
#     stopping criterion: RTOL
# Solution found after 40 iterations:
#     objective function f(sol) = 2.239984e+04
#     stopping criterion: RTOL
# Solution found after 40 iterations:
#     objective function f(sol) = 2.225726e+04
#     stopping criterion: RTOL
# Solution found after 40 iterations:
#     objective function f(sol) = 2.232379e+04
#     stopping criterion: RTOL
# Solution found after 40 iterations:
#     objective function f(sol) = 2.244928e+04
#     stopping criterion: RTOL
# Solution found after 40 iterations:
#     objective function f(sol) = 2.218110e+04
#     stopping criterion: RTOL
# Solution found after 40 iterations:
#     objective function f(sol) = 2.211073e+04
#     stopping criterion: RTOL
# Solution found after 39 iterations:
#     objective function f(sol) = 2.233265e+04
#     stopping criterion: RTOL
# Solution found after 40 iterations:
#     objective function f(sol) = 2.233665e+04
#     stopping criterion: RTOL
# Solution found after 40 iterations:
#     objective function f(sol) = 2.239484e+04
#     stopping criterion: RTOL
# Solution found after 40 iterations:
#     objective function f(sol) = 2.227472e+04
#     stopping criterion: RTOL
# Solution found after 40 iterations:
#     objective function f(sol) = 2.247311e+04
#     stopping criterion: RTOL
# Solution found after 40 iterations:
#     objective function f(sol) = 2.226165e+04
#     stopping criterion: RTOL
# Solution found after 40 iterations:
# ...
#     objective function f(sol) = 1.743888e+03
#     stopping criterion: RTOL
# Solution found after 2 iterations:
#     objective function f(sol) = 1.699790e+03
#     stopping criterion: RTOL
# Solution found after 2 iterations:
#     objective function f(sol) = 1.704483e+03
#     stopping criterion: RTOL
# Solution found after 2 iterations:
#     objective function f(sol) = 1.708223e+03
#     stopping criterion: RTOL
# Solution found after 2 iterations:
#     objective function f(sol) = 1.627139e+03
#     stopping criterion: RTOL
# Solution found after 2 iterations:
#     objective function f(sol) = 1.692916e+03
#     stopping criterion: RTOL
# Solution found after 2 iterations:
#     objective function f(sol) = 1.729135e+03
#     stopping criterion: RTOL
# Solution found after 2 iterations:
#     objective function f(sol) = 1.667489e+03
#     stopping criterion: RTOL
# Solution found after 2 iterations:
#     objective function f(sol) = 1.737205e+03
#     stopping criterion: RTOL
# Solution found after 2 iterations:
#     objective function f(sol) = 1.689172e+03
#     stopping criterion: RTOL
# Solution found after 2 iterations:
#     objective function f(sol) = 1.677506e+03
#     stopping criterion: RTOL
# Solution found after 2 iterations:
#     objective function f(sol) = 1.636338e+03
#     stopping criterion: RTOL
# Solution found after 2 iterations:
#     objective function f(sol) = 1.659816e+03
#     stopping criterion: RTOL
# Solution found after 2 iterations:
#     objective function f(sol) = 1.683366e+03
#     stopping criterion: RTOL
# Solution found after 2 iterations:
#     objective function f(sol) = 1.654507e+03
#     stopping criterion: RTOL
# Solution found after 2 iterations:
#     objective function f(sol) = 1.708073e+03
#     stopping criterion: RTOL
# Solution found after 2 iterations:
#     objective function f(sol) = 1.738712e+03
#     stopping criterion: RTOL
# Solution found after 2 iterations:
#     objective function f(sol) = 1.677380e+03
#     stopping criterion: RTOL
# Solution found after 2 iterations:
#     objective function f(sol) = 1.728051e+03
#     stopping criterion: RTOL
# Solution found after 2 iterations:
#     objective function f(sol) = 1.701222e+03
#     stopping criterion: RTOL
# Solution found after 2 iterations:
#     objective function f(sol) = 1.670369e+03
#     stopping criterion: RTOL
# Solution found after 2 iterations:
#     objective function f(sol) = 1.731640e+03
#     stopping criterion: RTOL
# Solution found after 2 iterations:
#     objective function f(sol) = 1.719359e+03
#     stopping criterion: RTOL
# Solution found after 2 iterations:
#     objective function f(sol) = 1.736264e+03
#     stopping criterion: RTOL
# Solution found after 2 iterations:
#     objective function f(sol) = 1.648048e+03
#     stopping criterion: RTOL
# Solution found after 2 iterations:
#     objective function f(sol) = 1.715388e+03
#     stopping criterion: RTOL
# Solution found after 2 iterations:
#     objective function f(sol) = 1.708612e+03
#     stopping criterion: RTOL
# Solution found after 2 iterations:
#     objective function f(sol) = 1.719881e+03
#     stopping criterion: RTOL
# Solution found after 2 iterations:
#     objective function f(sol) = 1.700850e+03
#     stopping criterion: RTOL
# Solution found after 2 iterations:
#     objective function f(sol) = 1.772885e+03
#     stopping criterion: RTOL
# Solution found after 2 iterations:
#     objective function f(sol) = 1.692377e+03
#     stopping criterion: RTOL
# Solution found after 2 iterations:
#     objective function f(sol) = 1.670626e+03
#     stopping criterion: RTOL
# Solution found after 2 iterations:
#     objective function f(sol) = 1.681327e+03
#     stopping criterion: RTOL
# Solution found after 2 iterations:
#     objective function f(sol) = 1.641491e+03
#     stopping criterion: RTOL
# Solution found after 2 iterations:
#     objective function f(sol) = 1.670751e+03
#     stopping criterion: RTOL
# Solution found after 2 iterations:
#     objective function f(sol) = 1.707883e+03
#     stopping criterion: RTOL
# Solution found after 2 iterations:
#     objective function f(sol) = 1.769859e+03
#     stopping criterion: RTOL
# Solution found after 2 iterations:
#     objective function f(sol) = 1.732400e+03
#     stopping criterion: RTOL
# Solution found after 2 iterations:
#     objective function f(sol) = 1.697952e+03
#     stopping criterion: RTOL
# Solution found after 2 iterations:
#     objective function f(sol) = 1.692360e+03
#     stopping criterion: RTOL
# Solution found after 2 iterations:
#     objective function f(sol) = 1.673938e+03
#     stopping criterion: RTOL
# Solution found after 2 iterations:
#     objective function f(sol) = 1.732217e+03
#     stopping criterion: RTOL
# Solution found after 2 iterations:
#     objective function f(sol) = 1.696061e+03
#     stopping criterion: RTOL
# Solution found after 2 iterations:
#     objective function f(sol) = 1.822680e+03
#     stopping criterion: RTOL
# Solution found after 2 iterations:
#     objective function f(sol) = 1.674091e+03
#     stopping criterion: RTOL
# Solution found after 2 iterations:
#     objective function f(sol) = 1.713736e+03
#     stopping criterion: RTOL
# Solution found after 2 iterations:
#     objective function f(sol) = 1.716301e+03
#     stopping criterion: RTOL
# Solution found after 2 iterations:
#     objective function f(sol) = 1.645878e+03
#     stopping criterion: RTOL
# Solution found after 2 iterations:
#     objective function f(sol) = 1.559290e+03
#     stopping criterion: RTOL
# Solution found after 2 iterations:
#     objective function f(sol) = 1.607331e+03
#     stopping criterion: RTOL
# Solution found after 2 iterations:
#     objective function f(sol) = 1.563777e+03
#     stopping criterion: RTOL
# Solution found after 2 iterations:
#     objective function f(sol) = 1.617268e+03
#     stopping criterion: RTOL
# Solution found after 2 iterations:
#     objective function f(sol) = 1.587512e+03
#     stopping criterion: RTOL
# Solution found after 2 iterations:
#     objective function f(sol) = 1.662716e+03
#     stopping criterion: RTOL
# Solution found after 2 iterations:
#     objective function f(sol) = 1.570597e+03
#     stopping criterion: RTOL
# Solution found after 2 iterations:
#     objective function f(sol) = 1.604792e+03
#     stopping criterion: RTOL
# Solution found after 2 iterations:
#     objective function f(sol) = 1.642059e+03
#     stopping criterion: RTOL
# Solution found after 2 iterations:
#     objective function f(sol) = 1.606613e+03
#     stopping criterion: RTOL
# Solution found after 2 iterations:
#     objective function f(sol) = 1.659850e+03
#     stopping criterion: RTOL
# Solution found after 2 iterations:
#     objective function f(sol) = 1.635571e+03
#     stopping criterion: RTOL
# Solution found after 2 iterations:
#     objective function f(sol) = 1.623208e+03
#     stopping criterion: RTOL
# Solution found after 2 iterations:
#     objective function f(sol) = 1.623214e+03
#     stopping criterion: RTOL
# Solution found after 2 iterations:
#     objective function f(sol) = 1.623974e+03
#     stopping criterion: RTOL
# Solution found after 2 iterations:
#     objective function f(sol) = 1.587743e+03
#     stopping criterion: RTOL
# Solution found after 2 iterations:
#     objective function f(sol) = 1.620530e+03
#     stopping criterion: RTOL
# Solution found after 2 iterations:
#     objective function f(sol) = 1.636035e+03
#     stopping criterion: RTOL
# Solution found after 2 iterations:
#     objective function f(sol) = 1.591624e+03
#     stopping criterion: RTOL
# Solution found after 2 iterations:
#     objective function f(sol) = 1.597233e+03
#     stopping criterion: RTOL
# Solution found after 2 iterations:
#     objective function f(sol) = 1.583701e+03
#     stopping criterion: RTOL
# Solution found after 2 iterations:
#     objective function f(sol) = 1.591235e+03
#     stopping criterion: RTOL
# Solution found after 2 iterations:
#     objective function f(sol) = 1.600589e+03
#     stopping criterion: RTOL
# Solution found after 2 iterations:
#     objective function f(sol) = 1.599916e+03
#     stopping criterion: RTOL
# Solution found after 2 iterations:
#     objective function f(sol) = 1.621630e+03
#     stopping criterion: RTOL
# Solution found after 2 iterations:
#     objective function f(sol) = 1.610134e+03
#     stopping criterion: RTOL
# Solution found after 2 iterations:
#     objective function f(sol) = 1.539589e+03
#     stopping criterion: RTOL
# Solution found after 2 iterations:
#     objective function f(sol) = 1.582625e+03
#     stopping criterion: RTOL
# Solution found after 2 iterations:
#     objective function f(sol) = 1.654811e+03
#     stopping criterion: RTOL
# Solution found after 2 iterations:
#     objective function f(sol) = 1.621560e+03
#     stopping criterion: RTOL
# Solution found after 2 iterations:
#     objective function f(sol) = 1.613864e+03
#     stopping criterion: RTOL
# Solution found after 2 iterations:
#     objective function f(sol) = 1.636953e+03
#     stopping criterion: RTOL
# Solution found after 2 iterations:
#     objective function f(sol) = 1.608708e+03
#     stopping criterion: RTOL
# Solution found after 2 iterations:
#     objective function f(sol) = 1.588208e+03
#     stopping criterion: RTOL
# Solution found after 2 iterations:
#     objective function f(sol) = 1.657084e+03
#     stopping criterion: RTOL
# Solution found after 2 iterations:
#     objective function f(sol) = 1.571059e+03
#     stopping criterion: RTOL
# Solution found after 2 iterations:
#     objective function f(sol) = 1.578521e+03
#     stopping criterion: RTOL
# Solution found after 2 iterations:
#     objective function f(sol) = 1.615675e+03
#     stopping criterion: RTOL
# Solution found after 2 iterations:
#     objective function f(sol) = 1.548505e+03
#     stopping criterion: RTOL
# Solution found after 2 iterations:
#     objective function f(sol) = 1.652053e+03
#     stopping criterion: RTOL
# Solution found after 2 iterations:
#     objective function f(sol) = 1.558978e+03
#     stopping criterion: RTOL
# Solution found after 2 iterations:
#     objective function f(sol) = 1.618418e+03
#     stopping criterion: RTOL
# Solution found after 2 iterations:
#     objective function f(sol) = 1.668335e+03
#     stopping criterion: RTOL
# Solution found after 2 iterations:
#     objective function f(sol) = 1.661470e+03
#     stopping criterion: RTOL
# Solution found after 2 iterations:
#     objective function f(sol) = 1.626017e+03
#     stopping criterion: RTOL
# Solution found after 2 iterations:
#     objective function f(sol) = 1.631765e+03
#     stopping criterion: RTOL
# Solution found after 2 iterations:
#     objective function f(sol) = 1.596483e+03
#     stopping criterion: RTOL
# Solution found after 2 iterations:
#     objective function f(sol) = 1.605291e+03
#     stopping criterion: RTOL
# Solution found after 2 iterations:
#     objective function f(sol) = 1.612483e+03
#     stopping criterion: RTOL
# Solution found after 2 iterations:
#     objective function f(sol) = 1.561656e+03
#     stopping criterion: RTOL
# Solution found after 2 iterations:
#     objective function f(sol) = 1.575911e+03
#     stopping criterion: RTOL
# Solution found after 2 iterations:
#     objective function f(sol) = 1.590700e+03
#     stopping criterion: RTOL
# Solution found after 2 iterations:
#     objective function f(sol) = 1.567351e+03
#     stopping criterion: RTOL
# Solution found after 2 iterations:
#     objective function f(sol) = 1.639678e+03
#     stopping criterion: RTOL
# Solution found after 2 iterations:
#     objective function f(sol) = 1.607547e+03
#     stopping criterion: RTOL
# Solution found after 2 iterations:
#     objective function f(sol) = 1.588009e+03
#     stopping criterion: RTOL
# Solution found after 2 iterations:
#     objective function f(sol) = 1.653470e+03
#     stopping criterion: RTOL
# Solution found after 2 iterations:
#     objective function f(sol) = 1.615953e+03
#     stopping criterion: RTOL
# Solution found after 2 iterations:
#     objective function f(sol) = 1.620205e+03
#     stopping criterion: RTOL
# Solution found after 2 iterations:
#     objective function f(sol) = 1.605685e+03
#     stopping criterion: RTOL
# Solution found after 2 iterations:
#     objective function f(sol) = 1.585509e+03
#     stopping criterion: RTOL
# Solution found after 2 iterations:
#     objective function f(sol) = 1.653041e+03
#     stopping criterion: RTOL
# Solution found after 2 iterations:
#     objective function f(sol) = 1.623183e+03
#     stopping criterion: RTOL
# Solution found after 2 iterations:
#     objective function f(sol) = 1.702943e+03
#     stopping criterion: RTOL
# Solution found after 2 iterations:
#     objective function f(sol) = 1.609360e+03
#     stopping criterion: RTOL
# Solution found after 2 iterations:
#     objective function f(sol) = 1.588204e+03
#     stopping criterion: RTOL
# Solution found after 2 iterations:
#     objective function f(sol) = 1.642492e+03
#     stopping criterion: RTOL
# Solution found after 2 iterations:
#     objective function f(sol) = 1.606286e+03
#     stopping criterion: RTOL
# Solution found after 2 iterations:
#     objective function f(sol) = 1.531306e+03
#     stopping criterion: RTOL
# Solution found after 2 iterations:
#     objective function f(sol) = 1.627705e+03
#     stopping criterion: RTOL
# Solution found after 2 iterations:
#     objective function f(sol) = 1.602124e+03
#     stopping criterion: RTOL
# Solution found after 2 iterations:
#     objective function f(sol) = 1.591155e+03
#     stopping criterion: RTOL
# Solution found after 2 iterations:
#     objective function f(sol) = 1.578503e+03
#     stopping criterion: RTOL
# Solution found after 2 iterations:
#     objective function f(sol) = 1.686390e+03
#     stopping criterion: RTOL
# Solution found after 2 iterations:
#     objective function f(sol) = 1.650024e+03
#     stopping criterion: RTOL
# Solution found after 2 iterations:
#     objective function f(sol) = 1.604399e+03
#     stopping criterion: RTOL
# Solution found after 2 iterations:
#     objective function f(sol) = 1.631425e+03
#     stopping criterion: RTOL
# Solution found after 2 iterations:
#     objective function f(sol) = 1.638501e+03
#     stopping criterion: RTOL
# Solution found after 2 iterations:
#     objective function f(sol) = 1.590587e+03
#     stopping criterion: RTOL
# Solution found after 2 iterations:
#     objective function f(sol) = 1.629797e+03
#     stopping criterion: RTOL
# Solution found after 2 iterations:
#     objective function f(sol) = 1.602233e+03
#     stopping criterion: RTOL
# Solution found after 2 iterations:
#     objective function f(sol) = 1.539446e+03
#     stopping criterion: RTOL
# Solution found after 2 iterations:
#     objective function f(sol) = 1.668442e+03
#     stopping criterion: RTOL
# Solution found after 2 iterations:
#     objective function f(sol) = 1.659906e+03
#     stopping criterion: RTOL
# Solution found after 2 iterations:
#     objective function f(sol) = 1.590284e+03
#     stopping criterion: RTOL
# Solution found after 2 iterations:
#     objective function f(sol) = 1.636117e+03
#     stopping criterion: RTOL
# Solution found after 2 iterations:
#     objective function f(sol) = 1.635755e+03
#     stopping criterion: RTOL
# Solution found after 2 iterations:
#     objective function f(sol) = 1.651724e+03
#     stopping criterion: RTOL
# Solution found after 2 iterations:
#     objective function f(sol) = 1.649042e+03
#     stopping criterion: RTOL
# Solution found after 2 iterations:
#     objective function f(sol) = 1.587079e+03
#     stopping criterion: RTOL
# Solution found after 2 iterations:
#     objective function f(sol) = 1.612158e+03
#     stopping criterion: RTOL
# Solution found after 2 iterations:
#     objective function f(sol) = 1.545783e+03
#     stopping criterion: RTOL
# Solution found after 2 iterations:
#     objective function f(sol) = 1.605955e+03
#     stopping criterion: RTOL
# Solution found after 2 iterations:
#     objective function f(sol) = 1.558477e+03
#     stopping criterion: RTOL
# Solution found after 2 iterations:
#     objective function f(sol) = 1.623178e+03
#     stopping criterion: RTOL
# Solution found after 2 iterations:
#     objective function f(sol) = 1.616042e+03
#     stopping criterion: RTOL
# Solution found after 2 iterations:
#     objective function f(sol) = 1.579785e+03
#     stopping criterion: RTOL
# Solution found after 2 iterations:
#     objective function f(sol) = 1.607793e+03
#     stopping criterion: RTOL
# Solution found after 2 iterations:
#     objective function f(sol) = 1.632545e+03
#     stopping criterion: RTOL

# %% [markdown]
# Plot both phase transition matrices as images with a colorbar. Make sure to properly name the axes and title the images.

# %%
# Your code here.
fig = plt.figure()
ax = fig.add_subplot(111)
im = ax.imshow(pt_matrix_1norm)
plt.colorbar(im)
plt.xlabel("threshold")
plt.ylabel("mn-ratio")
plt.title('Phase Transition 1-norm minimization')
plt.show()
plt.close(fig)

fig = plt.figure()
ax = fig.add_subplot(111)
im = ax.imshow(pt_matrix_2norm)
plt.colorbar(im)
plt.xlabel("threshold")
plt.ylabel("mn-ratio")
plt.title('Phase Transition 2-norm minimization')
plt.show()
plt.close(fig)

# %% [markdown]
# ### Question 18
#
# Do the phase transition plots above provide any justification for choosing one $p-$norm interpolation over the other? Why?

# %% [markdown]
# **Our answer:**
#
# * At the mn-ratio 0.2, they both perform about the same, however as we increase the mn-ratio, p1 outperforms p2.
#
# * Overall, the p1 norm performs better for our graph (we get lower errors as we increase the mn-ratio). However, it takes longer to converge. This is because the p1 norm is more robust against outliers, whereas the p2 norm is known to be influenced more by outliers.
#
# * The p2 norm takes less time to converge but gives slightly higher errors when we are sampling more data points.
