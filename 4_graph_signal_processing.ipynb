# %% [markdown]
# # [NTDS'18] milestone 4: graph signal processing
# [ntds'18]: https://github.com/mdeff/ntds_2018
#
# [Rodrigo Pena](https://people.epfl.ch/254838), [EPFL LTS2](http://lts2.epfl.ch)

# %% [markdown]
# ## Students
#
# * Team: `32`
# * Students: `George Adaimi, Okan Altingovde, Isinsu Katircioglu, Sena Kiciroglu`
# * Dataset: `FMA`

# %% [markdown]
# ## Rules
#
# * Milestones have to be completed by teams. No collaboration between teams is allowed.
# * Textual answers shall be short. Typically one to two sentences.
# * Code has to be clean.
# * You cannot import any other library than we imported.
# * When submitting, the notebook is executed and the results are stored. I.e., if you open the notebook again it should show numerical results and plots. We won't be able to execute your notebooks.
# * The notebook is re-executed from a blank state before submission. That is to be sure it is reproducible. You can click "Kernel" then "Restart & Run All" in Jupyter.

# %% [markdown]
# ## Objective
#
# The goal of this milestone is to do some Graph Signal Processing (GSP) on the data of your project.
#
# ### A note about plotting
#
# There are several questions in this milestone that ask you to plot a signal on your network.
# There are several ways from which you could approach it.
# In all cases, compute the position of the nodes a single time at the beginning, as this is likely to be a costly operation.
# Using a single layout for all the graph plots will also make it easier to compare the plots.
# Indeed, the only thing changing between plots is the signal displayed.
# You can represent the features/labels lying on the graph via node **colors**.
# To do so, make sure to have a consistent color map throughout and remember to display a colorbar and scale in all plots, so that we can tell what numbers the colors represent.
#
# * An option is to use the **Laplacian eigenmaps** that you have seen in the previous milestone to embed your graph on the plane. For example:
#   ```
#   from matplotlib import pyplot as plt
#   plt.scatter(eigenvectors[:, 1], eigenvectors[:, 2], c=signal, alpha=0.5)
#   plt.colorbar()
#   ```
# * Another option is to use the plotting capabilities of **[NetworkX](https://networkx.github.io)**.
#   See the documentation of its [drawing methods](https://networkx.github.io/documentation/stable/reference/drawing.html).
#   For example:
#   ```
#   import networkx as nx
#   graph = nx.from_scipy_sparse_matrix(adjacency)
#   coords = nx.spring_layout(graph)  # Force-directed layout.
#   coords = eigenvectors[:, 1:3]  # Laplacian eigenmaps.
#   nx.draw_networkx_nodes(graph, coords, node_size=60, node_color=signal)
#   nx.draw_networkx_edges(graph, coords, alpha=0.3)
#   ```
# * Another option is to use the plotting capabilities of the **[PyGSP](https://github.com/epfl-lts2/pygsp)**, a Python package for Graph Signal Processing.
#   **Note that your are forbidden to use the PyGSP for anything else than plotting.**
#   See the documentation of its [plotting utilities](https://pygsp.readthedocs.io/en/stable/reference/plotting.html).
#   For example:
#   ```
#   import pygsp as pg
#   graph = pg.graphs.Graph(adjacency)
#   graph.set_coordinates('spring')  # Force-directed layout.
#   graph.set_coordinates(eigenvectors[:, 1:3])  # Laplacian eigenmaps.
#   graph.plot_signal(signal)
#   ```
# * Yet another option is to save your graph on disk, use **[Gephi](https://gephi.org)** externally, to visualize the graph, save the graph with the Gephi coordinates and finally load the nodes coordinates back into the notebook.
#
# We encourage you to try all the above methods before making your choice. Then be consistent and use only one throughout the milestone.
# NetworkX and PyGSP should already be installed in your environement. If that's not the case, install with `conda install networkx pygsp` (after activating the `ntds_2018` environment).

# %% [markdown]
# ## 0 - Load your network

# %%
# %matplotlib inline

# %% [markdown]
# If you get a `No module named 'pyunlocbox'` error when running the below cell, install the [pyunlocbox](https://github.com/epfl-lts2/pyunlocbox) with `conda install pyunlocbox` (after activating the `ntds_2018` environment).

# %%
import numpy as np
from scipy import sparse
import scipy.sparse.linalg
from matplotlib import pyplot as plt
from pyunlocbox import functions, solvers

import pygsp as pg

# %% [markdown]
# For this milestone, all we will need is a set of features/labels for each of the nodes on the network, as well as the Laplacian, $L,$ and Gradient, $\nabla_G,$ matrices that you have computed for your network while working on milestone 3.
#
# Import those objects in the cell below (or recompute the Laplacian and Gradient from your stored adjacency matrix, if you wish).
#
# _Note_: If your features/labels are not floating-point numbers, please convert them. For example, if your data has labels "cat" and "dog" for nodes that represent cats or dogs, respectively, you may assign the number `1.0` for the label "cat" and the number `-1.0` for the label "dog".

# %%
adjacency =  np.load('adjacency_noDisconnectedNodes_mfccStdMeanSkewKurtosisMedian.npy')# the adjacency matrix
n_nodes = adjacency.shape[0]
n_edges =  np.count_nonzero(adjacency)//2# the number of edges in the network

adjacency_unweighted = np.zeros(adjacency.shape)
adjacency_unweighted[adjacency>0] = 1

D = np.diag(adjacency.sum(axis=1))
L = D - adjacency
sqrt_D = np.power(np.linalg.inv(D),0.5)

# %%
normalized_incidence = np.zeros((n_nodes, n_edges))
edge_map = np.full((n_nodes, n_nodes), -1)
edge_indices = np.where(adjacency > 0)
next_edge = 0
for i, j in (zip(edge_indices[0], edge_indices[1])):
    if edge_map[i, j] == -1:
        edge_map[i, j] = next_edge
        edge_map[j, i] = next_edge
        normalized_incidence[i, next_edge] = np.sqrt(adjacency[i,j])*sqrt_D[i,i]
        next_edge += 1
    else:
        normalized_incidence[i, edge_map[i, j]] = -np.sqrt(adjacency[i,j])*sqrt_D[i,i]

# %%
#Question part
laplacian =sparse.csr_matrix(sqrt_D@L@sqrt_D)
gradient = sparse.csr_matrix(np.transpose(normalized_incidence))
labels = np.load('labels.npy') #the labels for hip-hop and rock (-1 and 1)
print('Number of nodes: ', n_nodes)
# Out:
# Number of nodes:  2000

# %% [markdown]
# ## 1 - Graph Fourier Transform
#
# In this section we will observe how your feature/label vector looks like in the "Graph Fourier" domain.

# %% [markdown]
# ### Question 1
#
# Compute the Fourier basis vectors and the Laplacian eigenvalues. Make sure to order those from smaller to larger, $\lambda_0 \leq \lambda_1 \leq \dots \leq \lambda_{N-1},$ and use the same ordering for the Fourier basis vectors.

# %%
eigenvalues, eigenvectors = np.linalg.eigh(laplacian.toarray())
## Sorting Eigenvalues and EigenVectors
sorted_indexes = eigenvalues.argsort()
eigenvalues = np.array(eigenvalues[sorted_indexes])
eigenvectors = np.array(eigenvectors[sorted_indexes])

e = eigenvalues# Ordered Laplacian eigenvalues.
U = eigenvectors# Ordered graph Fourier basis.

# %%
graph = pg.graphs.Graph(adjacency,lap_type = 'normalized')
graph.set_coordinates('spring')
plot_list = [0,1,2,-1]

# %% [markdown]
# Plot the first 3 and the last Fourier basis vectors as signals on your graph. Clearly indicate which plot belongs to which basis vector.

# %%
# Your code here.
fig, axes = plt.subplots(4, 1, figsize=(10, 3))
for i, plot_ind in enumerate(plot_list):
    ax = axes[i]#[i%2]
    graph.plot_signal(np.asarray(U)[:, plot_ind])
    plt.title('Eigenvector {}'.format(plot_ind+1 if plot_ind>= 0 else n_nodes))
    ax.set_axis_off()
fig.tight_layout()
#################REMOVE ALL EVIDENCE


#graph.compute_fourier_basis()

#graph.set_coordinates('line1D')
#fig = plt.figure()
#index = np.arange(U.shape[0])
#plt.plot(index, np.squeeze(np.asarray(graph.U[:,0])), label="1st")
#plt.plot(index, np.squeeze(np.asarray(graph.U[:,1])), label="2nd")
#plt.plot(index, np.squeeze(np.asarray(graph.U[:,2])), label="3rd")
#plt.plot(index, np.squeeze(np.asarray(graph.U[:,-1])), label="last")
#plt.legend()
#plt.show()
#plt.close(fig)
#for i, ax in enumerate(axes):
#graph.plot_signal(graph.U[:, [0,1,2,-1]])
#    _ = ax.set_title('Eigenvector {}'.format(i+2))
#    ax.set_axis_off()
#fig.tight_layout()

# %% [markdown]
# ### Question 2
#
# What can you observe in terms of local variations when comparing the basis vectors corresponding to the smallest eigenvalues to those corresponding to the largest eigenvalue? How would this justify the interpretation of the eigenvalues as "graph frequencies"?

# %% [markdown]
# **Your answer here.**

# %% [markdown]
# ### Question 3
#
# Implement a function that returns the Graph Fourier Transform (GFT) of a given vector $x \in \mathbb{R}^{N},$ with respect to your graph, and a function that computes the corresponding inverse GFT (iGFT).

# %%
def GFT(x):
    return eigenvectors.T@np.array(x) # Your code here.

def iGFT(x):
    return eigenvectors@np.array(x) # Your code here.

# %% [markdown]
# ### Question 4
#
# Plot your feature/label vector as a signal on your graph

# %%
# Your code here.
graph.plot_signal(labels)

# %% [markdown]
# Plot the absolute values of the GFT of your feature/label signal as a function of the graph eigenvalues. Make sure to add a marker indicating the position of each graph eigenvalue, and remember to properly name the axes.

# %%
# Your code here.
gft_of_labels = np.abs(GFT(labels))

fig = plt.figure()
plt.plot(e, gft_of_labels, marker = "*")
plt.xlabel("eigenvalues")
plt.ylabel("GFT of label")
plt.show()
plt.close(fig)

# %% [markdown]
# ### Question 5
#
# Discuss the behavior of the GFT that you plotted in the last question via comparing the plot of your label signal and those of the Fourier basis of Question 1. Would you consider your labels a "low-pass" or "high-pass" signal, or yet something else entirely?

# %% [markdown]
# **Your answer here.**

# %% [markdown]
# ## 2 - Filtering on graphs
#
# In this section we will check how filtered Dirac impulses diffuse on your graph.

# %% [markdown]
# ### Question 6
#
# Implement the following three filter kernels and the graph filtering operation.
#
# - The **heat kernel** is supposed to take in a vector of eigenvalues `e` and a parameter `t` and output a vector of evaluations of the heat kernel at those eigenvalues (see the course slides for help).
# - The **inverse filter** kernel is supposed to take in a vector of eigenvalues `e` and a parameter `t` and implement spectrally the  filter defined in the node domain by $f_{out}  = (I + t L)^{-1} f_{in},$ where $f_{in}, f_{out} \in \mathbb{R}^{N}$ are, repectively, the input and output signals to the filter.
# - The **rectangle kernel** takes in a vector of eigenvalues `e` and parameters `l_min` and `l_max` and returns `1.0` at coordinates satisfying $(e[l] \geq l_{min}) \wedge (e[l] \leq l_{max}),$ and `0.0` otherwise.
# - The **graph filtering** operation takes a graph signal $x \in \mathbb{R}^{N}$, a spectral graph `kernel` and a set of keyworded variables, and returns the corresponding filtered signal.
#     - _Hint:_ Remember that you have implemented the `GFT` and `iGFT` operations in Question 3.
#     - The `**kwargs` is a placeholder to collect supplementary pairs of keyword-values that are not known by the implementation before execution time.
#       The `kwargs` variable is a dictionary whose keyes and values are the parameter names and values.
#       This is useful to allow both `graph_filter(x, heat_kernel, tau=1.0)` and `graph_filter(x, rectangle_kernel, lambda_min=0.0, lambda_max=1.0)` to be valid calls from the same implementation.
#       One can then defer the keyword-value assignment to the `kernel` call: `foo = kernel(bar, **kwargs)`.

# %%
def heat_kernel(e, t):
    return np.exp(-e*t)#/(e[-1]*1.01))

def inverse_kernel(e, t):
    return np.linalg.inv(np.eye(n_nodes)+t*L)

def rectangle_kernel(e, l_min, l_max): 
    kernel = np.zeros([n_nodes,])
    kernel[np.logical_and(e >= l_min, e <= l_max)] = 1
    return kernel

def graph_filter(x, kernel, **kwargs):
    gft_x = GFT(x)
    out_kernel = kernel(e, **kwargs)
    print(out_kernel.shape)
    filtered_x = iGFT(out_kernel*gft_x)
    return filtered_x

# %% [markdown]
# ### Question 7
#
# Plot all three filter kernels in the spectral domain. Remember to properly name the axes and title the plots. Choose filter parameters that best approximate the behavior of the GFT of your feature/label signal (as seen in Question 4).

# %%
# Your code here.
heat_kernel_res = heat_kernel(e, t=10)
rectangle_kernel_res = rectangle_kernel(e, l_min = 0.2, l_max = 0.8)

fig = plt.figure()
plt.plot(e, heat_kernel_res, marker = "*")
plt.title("Heat kernel")
plt.xlabel("Frequency (Eigenvalues)")
plt.ylabel("Kernel value")
plt.show()
plt.close(fig)

fig = plt.figure()
plt.title("Inverse kernel")
plt.xlabel("Frequency (Eigenvalues)")
plt.ylabel("Kernel value")
plt.show()
plt.close(fig)

fig = plt.figure()
plt.plot(e, rectangle_kernel_res, marker = "*")
plt.title("Rectangle kernel")
plt.xlabel("Frequency (Eigenvalues)")
plt.ylabel("Kernel value")
plt.show()
plt.close(fig)

# %% [markdown]
# ### Question 8
#
# Consider two Dirac impulses arbitrarily placed on your graph. Plot their filtered versions by the three filter kernels implemented in Question 6.

# %%
# Your code here.
diracs = np.zeros([n_nodes,])
dirac_pos = [20]
diracs[dirac_pos] = 1

filtered_s_heat = graph_filter(diracs, heat_kernel, t=10)
filtered_s_rect = graph_filter(diracs, rectangle_kernel, l_min = 0.2, l_max = 0.8)

graph.plot_signal(filtered_s_heat)
plt.title("Heat")
graph.plot_signal(filtered_s_rect)
plt.title("Rectangular")
#graph.plot_signal(labels)
# Out:
# (2000,)
# (2000,)
# Text(0.5, 1.0, 'Rectangular')

# %% [markdown]
# Comment on the "diffusion" of the Diracs induced by the filters. What does it say about the "communication" of information across your network? Relate that to the network connectivity measures that you analyzed during the previous milestones.

# %% [markdown]
# **Your answer here.**

# %% [markdown]
# ## 3 - De-noising
#
# In this section we will add some centered Gaussian noise to your feature/label signal and attempt to recover it.

# %% [markdown]
# ### Question 9
#
# In the cell below, set the noise variance $\sigma^2$ by making sure that the signal-to-noise ratio $SNR = \frac{\operatorname{Var}(\text{labels})}{\sigma^2}$ is about  $1.5$.
#
# _Note:_ Actually, you might want to play with the noise variance here and set it to different values and see how the denoising filters behave.

# %%
SNR = 1.5
noise_variance = np.var(labels)/SNR # Your code here.
noisy_measurements = labels + noise_variance * np.random.randn(n_nodes)

# %% [markdown]
# ### Question 10
#
# In the denoising setting, a common graph signal processing assumption is that the signal $z$ that we want to recover is "smooth", in the sense that $\|\nabla_G z\|_2 = \sqrt{z^{\top} L z}$ is small, while remaining "close" to the measurements that we start with. This leads to denoising by solving the following optimization problem:
#
# $$
# z^\star = \text{arg} \, \underset{z \in \mathbb{R}^{N}}{\min} \, \|z - y\|_2^2 + \gamma z^{\top} L z,
# $$
#
# where $y \in \mathbb{R}^{N}$ is the vector of noisy measurements.
#
# Derive the close form solution to this problem giving $z^\star$ as a function of $y$, $\gamma$ and $L$. Does this solution correspond to any graph filtering operation that you know?

# %% [markdown]
# **Your answer here.**

# %% [markdown]
# ### Question 11
#
# Now, denoise the noisy measurements by passing them through the filters that you implemented in Question 6. Choose the filter parameters based on the behavior of the GFT of your original label signal (this is the prior knowledge that you input to the problem).

# %%
## Filter Parameters
t_heat = 10
l_min = 0.2
l_max = 0.8

z_heat_denoised = graph_filter(noisy_measurements, heat_kernel, t=t_heat) # Your code here.
#z_inv_denoised = graph_filter(noisy_measurements, inverse_kernel, t=t_heat)# Your code here.
z_rect_denoised = graph_filter(noisy_measurements, rectangle_kernel, l_min = l_min, l_max = l_max)# Your code here.
# Out:
# (2000,)
# (2000,)

# %% [markdown]
# Plot, on your graph, the original label signal, the noisy measurements, and the three denoised version obtained above. Report on each plot the value of the corresponding relative error
# $$
# \text{rel-err} = \frac{\|\text{labels} - z \|_2}{\|\text{labels}\|_2},
# $$
# where $z$ is the plotted signal.

# %%
# Your code here.
def relative_error(signal):
    return np.linalg.norm((labels-signal))/np.linalg.norm(labels)

graph.plot_signal(labels)
plt.title("Original Labels")
plt.text(0.32, 10, 'rel-err: {:.2E}'.format(relative_error(labels)), horizontalalignment='center',verticalalignment='baseline', transform=ax.transAxes,bbox=dict(facecolor='red', alpha=0.5))
graph.plot_signal(noisy_measurements)
plt.text(0.32, 10, 'rel-err: {:.2E}'.format(relative_error(noisy_measurements)), horizontalalignment='center',verticalalignment='baseline', transform=ax.transAxes,bbox=dict(facecolor='red', alpha=0.5))
plt.title("Noisy Labels")

graph.plot_signal(z_heat_denoised)
plt.text(0.32, 10, 'rel-err: {:.2E}'.format(relative_error(z_heat_denoised)), horizontalalignment='center',verticalalignment='baseline', transform=ax.transAxes,bbox=dict(facecolor='red', alpha=0.5))
plt.title("Heat Denoised")

#graph.plot_signal(z_inv_denoised)
#plt.text(0.5, 0.9, 'rel-err: {}'.format(relative_error(z_inv_denoised)), horizontalalignment='center',verticalalignment='baseline', transform=ax.transAxes,bbox=dict(facecolor='red', alpha=0.5))
#plt.title("Inverse Denoised")

graph.plot_signal(z_rect_denoised)
plt.text(0.32, 10, 'rel-err: {:.2E}'.format(relative_error(z_rect_denoised)), horizontalalignment='center',verticalalignment='baseline', transform=ax.transAxes,bbox=dict(facecolor='red', alpha=0.5))
plt.title("Rect Denoised")
# Out:
# Text(0.5, 1.0, 'Rect Denoised')

# %% [markdown]
# Finally, overlay on the same plot the GFT of all five signals above.

# %%
# Your code here.
gft_of_heat = GFT(z_heat_denoised)
#gft_of_inv = GFT(z_inv_denoised)
gft_of_rect = GFT(z_rect_denoised)

fig = plt.figure()
plt.plot(e, gft_of_heat, marker = "*",label='Heat GFT')
#plt.plot(e, gft_of_inv, marker = "o",label='Inverse GFT')
plt.plot(e, gft_of_rect, marker = "x",label='Rect GFT')
plt.xlabel("eigenvalues")
plt.ylabel("GFT of Signal")
plt.legend(loc='upper left')
plt.show()
plt.close(fig)

# %% [markdown]
# ### Question 12
#
# Comment on which denoised version seems to best match the original label signal. What is the underlying assumption behind the three filtering approaches? Do you think it holds for your label signal? Why?

# %% [markdown]
# **Your answer here.**

# %% [markdown]
# ## 4 - Transductive learning
#
# It is often the case in large networks that we can only afford to query properties/labels on a small subset of nodes. Nonetheless, if the underlying labels signal is "regular" enough, we might still be able to recover a good approximation of it by solving an offline variational problem, with constraints on the values of the measured nodes.
#
# In this section, we will be interested in solving such transductive learning problems by minimizing a (semi-) p-norm of the graph gradient applied to the signal of interest:
#
# $$
# \text{arg} \, \underset{z|_S = y}{\min} \|\nabla_G z\|_p^p,
# $$
#
# where $S$ is the set of measured nodes.
#
# In English, we can say that we are looking for solutions with small "aggregated local variations", as measured by $\|\nabla_G z\|_p^p = \sum_{i=1}^{n} \sum_{j=1}^{n} \left( \sqrt{W_{ij}} |z[i] - z[j]| \right)^p,$ while satisfying the measurement constraints $z[i] = y[i]$ for $i \in S.$
#
# We will work with two cases, according to the choices $p=1$ or $p=2.$ For $p=1,$ the problem is known as "interpolation by graph total-variation minimization," whereas for $p=2$ it is sometimes called "interpolation by Tikhonov regularization".
#
# In order to solve these variational problems with the black-box solver provided to you, you will use the [pyunlocbox](https://pyunlocbox.readthedocs.io). This toolbox implements iterative solvers based on so-called ["proximal-splitting"](https://en.wikipedia.org/wiki/Proximal_gradient_method) methods.

# %% [markdown]
# ### Question 13
#
# Throughout this section, we will consider only a binarized version of your label signal. If your variable `labels` currently has values other than $\{-1, 1\},$ threshold them so that those are the only values taken in this vector. This can be done for example by choosing a number $t \in \mathbb{R}$ and then setting $\text{labels_bin}[i] = 1$ if $\text{labels}[i] \geq t$ and $\text{labels_bin}[i] = 0$ otherwise.

# %%
labels_bin = labels # Your code here.

# %% [markdown]
# Now, subsample this binarized label signal by $70\%$ by choosing, uniformly at random, $30\%$ of the nodes whose labels we will keep.
#
# You will do this by computing a "measurement mask" vector `w` with `1.0`'s at the measured coordinates, and $0.0$'s otherwise.

# %%
mn_ratio = 0.3
m = int(mn_ratio * n_nodes)  # Number of measurements.
np.random.seed(5)
w= np.zeros((n_nodes,))
w[np.random.choice(n_nodes, m, replace=False)] = 1# Your code here.

# %% [markdown]
# Plot the subsampled signal on the graph. _Hint:_ you might want to set to `numpy.nan` the values of the un-measured nodes for a cleaner plot.

# %%
# Your code here.
labels_for_graphing = labels_bin.astype(np.float32)
labels_for_graphing[w==0] = np.nan
graph.plot_signal(labels_for_graphing)
plt.title("Subsampled Signal on the graph")
# Out:
# /usr/local/lib/python3.7/site-packages/numpy/core/_methods.py:32: RuntimeWarning: invalid value encountered in reduce
#   return umr_minimum(a, axis, None, out, keepdims, initial)
# /usr/local/lib/python3.7/site-packages/numpy/core/_methods.py:28: RuntimeWarning: invalid value encountered in reduce
#   return umr_maximum(a, axis, None, out, keepdims, initial)
# Text(0.5, 1.0, 'Subsampled Signal on the graph')

# %% [markdown]
# ### Interlude
#
# For the solution of the variational problems you can use the following function as a "black-box".
#
# You will just need to provide a `gradient` matrix (which you should already have from Section 0), and an orthogonal projection operator `P` onto the span of the measured coordinates (made precise in the next question).

# %%
def graph_pnorm_interpolation(gradient, P, x0=None, p=1., **kwargs):
    r"""
    Solve an interpolation problem via gradient p-norm minimization.

    A signal :math:`x` is estimated from its measurements :math:`y = A(x)` by solving
    :math:`\text{arg}\underset{z \in \mathbb{R}^n}{\min}
    \| \nabla_G z \|_p^p \text{ subject to } Az = y` 
    via a primal-dual, forward-backward-forward algorithm.

    Parameters
    ----------
    gradient : array_like
        A matrix representing the graph gradient operator
    P : callable
        Orthogonal projection operator mapping points in :math:`z \in \mathbb{R}^n` 
        onto the set satisfying :math:`A P(z) = A z`.
    x0 : array_like, optional
        Initial point of the iteration. Must be of dimension n.
        (Default is `numpy.random.randn(n)`)
    p : {1., 2.}
    kwargs :
        Additional solver parameters, such as maximum number of iterations
        (maxit), relative tolerance on the objective (rtol), and verbosity
        level (verbosity). See :func:`pyunlocbox.solvers.solve` for the full
        list of options.

    Returns
    -------
    x : array_like
        The solution to the optimization problem.

    """
    
    grad = lambda z: gradient.dot(z)
    div = lambda z: gradient.transpose().dot(z)

    # Indicator function of the set satisfying :math:`y = A(z)`
    f = functions.func()
    f._eval = lambda z: 0
    f._prox = lambda z, gamma: P(z)

    # :math:`\ell_1` norm of the dual variable :math:`d = \nabla_G z`
    g = functions.func()
    g._eval = lambda z: np.sum(np.abs(grad(z)))
    g._prox = lambda d, gamma: functions._soft_threshold(d, gamma)

    # :math:`\ell_2` norm of the gradient (for the smooth case)
    h = functions.norm_l2(A=grad, At=div)

    stepsize = (0.9 / (1. + scipy.sparse.linalg.norm(gradient, ord='fro'))) ** p

    solver = solvers.mlfbf(L=grad, Lt=div, step=stepsize)

    if p == 1.:
        problem = solvers.solve([f, g, functions.dummy()], x0=x0, solver=solver, **kwargs)
        return problem['sol']
    if p == 2.:
        problem = solvers.solve([f, functions.dummy(), h], x0=x0, solver=solver, **kwargs)
        return problem['sol']
    else:
        return x0

# %% [markdown]
# ### Question 14
#
# During the iterations of the algorithm used for solving the variational problem, we have to make sure that the labels at the measured nodes stay the same. We will do this by means of an operator `P` which, given a vector $a \in \mathbb{R}^{N},$ returns another vector $b \in \mathbb{R}^{N}$ satisfying $b[i] = \text{labels_bin}[i]$ for every node $i$ in the set $S$ of known labels, and $b[i] = a[i]$ otherwise. Write in the cell below the function for this orthogonal projection operator `P`.
#
# _Hint:_ remember you have already computed the mask `w`.

# %%
def P(a):
    # Your code here.
    b = a
    b[w==1] = labels_bin[w==1]
    return b

# %% [markdown]
# ### Question 15
#
# Solve the variational problems for $p = 1$ and $p = 2$. Record the solution for the $1-$norm minimization under `sol_1norm_min` and the one for $2-$norm minimization under `sol_2norm_min`.
#
# Compute also binarized versions of these solutions by thresholding the values with respect to $0$, that is, non-negative values become `1.0`, while negative values become `-1.0`. Store those binarized versions under `sol_1norm_bin` and `sol_2norm_bin`, respectively.

# %%
sol_1norm_min = graph_pnorm_interpolation(gradient, P, x0=np.random.randn(n_nodes), p=1.)# Your code here.

sol_2norm_min = graph_pnorm_interpolation(gradient, P, x0=np.random.randn(n_nodes), p=2.) # Your code here.

threshold = 0

sol_1norm_bin = np.zeros(sol_1norm_min.shape)
sol_1norm_bin[sol_1norm_min >= threshold] = 1 # Your code here.
sol_1norm_bin[sol_1norm_min < threshold] = -1

sol_2norm_bin = np.zeros(sol_2norm_min.shape)
sol_2norm_bin[sol_2norm_min >= threshold] = 1 # Your code here.
sol_2norm_bin[sol_2norm_min < threshold] = -1

graph.plot_signal(labels_bin)
plt.text(0.32, 10, 'rel-err: {:.2E}'.format(relative_error(labels_bin)), horizontalalignment='center',verticalalignment='baseline', transform=ax.transAxes,bbox=dict(facecolor='red', alpha=0.5))
plt.title("Labels_bin")

graph.plot_signal(sol_1norm_min)
plt.text(0.32, 10, 'rel-err: {:.2E}'.format(relative_error(sol_1norm_min)), horizontalalignment='center',verticalalignment='baseline', transform=ax.transAxes,bbox=dict(facecolor='red', alpha=0.5))
plt.title("1−norm minimization")

graph.plot_signal(sol_2norm_min)
plt.text(0.32, 10, 'rel-err: {:.2E}'.format(relative_error(sol_2norm_min)), horizontalalignment='center',verticalalignment='baseline', transform=ax.transAxes,bbox=dict(facecolor='red', alpha=0.5))
plt.title("2−norm minimization")

graph.plot_signal(sol_1norm_bin)
plt.text(0.32, 10, 'rel-err: {:.2E}'.format(relative_error(sol_1norm_bin)), horizontalalignment='center',verticalalignment='baseline', transform=ax.transAxes,bbox=dict(facecolor='red', alpha=0.5))
plt.title("Binarized 1−norm minimization")

graph.plot_signal(sol_2norm_bin)
plt.text(0.32, 10, 'rel-err: {:.2E}'.format(relative_error(sol_2norm_bin)), horizontalalignment='center',verticalalignment='baseline', transform=ax.transAxes,bbox=dict(facecolor='red', alpha=0.5))
plt.title("Binarized 2−norm minimization")
# Out:
# Solution found after 200 iterations:
#     objective function f(sol) = 9.180205e+04
#     stopping criterion: MAXIT
# Solution found after 162 iterations:
#     objective function f(sol) = 1.666935e+03
#     stopping criterion: RTOL
# Text(0.5, 1.0, 'Binarized 2−norm minimization')

# %% [markdown]
# Plot, on your graph, the original `labels_bin` signal, as well as the solutions to the variational problems (both binarized and otherwise). Indicate on each plot the value of the relative error $\text{rel-err} = \frac{\|\text{labels_bin} - z\|_2}{\|\text{labels_bin}\|_2}$, where $z$ is the signal in the corresponding plot.

# %% [markdown]
# ### Question 16
#
# Now that you have got a feeling for the sort of solutions that the transductive learning problems studied can give, we will see what is the effect of the number of measurements on the accuracy of both $p-$norm minimization problems.
#
# Towards this goal, you will write a `phase_transition()` function. This function will basically go over all the procedures that you have implemented in this section, but for varying numbers of measurements and thresholding values. It will also compute the relative error, $\text{rel-err},$ of the solutions and average them over a number of trials.
#
# The output of the `phase_transition()` function has to be a matrix with `len(mn_ratios)` columns and `len(thresholds)` rows. Each pixel $(i,j)$ in the output matrix has to contain the average, over `n_trials` trials, of the relative error $\text{rel-err}$ in the binarized (with threshold `thresholds[i]`) solution given by `graph_pnorm_interpolation()` from observing an `mn_ratios[j]` fraction of nodes. The randomness comes from a different choice of mask `w` at each trial, hence the averaging.
#
# The interest of this phase transition matrix is to assess what level of recovery error one could expect for a certain fraction of measurements and a certain threshold level.

# %%
def phase_transition(mn_ratios, thresholds, n_trials, labels, p):
    ## Initialization
    pt_matrix = np.zeros((len(thresholds),len(mn_ratios)))
    np.random.seed(5)
    
    for column_ind, mn_ratio in enumerate(mn_ratios):
        m = int(mn_ratio * n_nodes)
        for row_ind, threshold in enumerate(thresholds):
            labels_bin = np.empty((len(labels),))
            labels_bin[labels<threshold] = -1 
            labels_bin[labels>=threshold] = 1 
            for _ in range(n_trials):
                w = np.zeros((n_nodes,))
                w[np.random.choice(n_nodes, m, replace=False)] = 1
                sol_norm = graph_pnorm_interpolation(gradient, P, x0=np.random.randn(n_nodes), p=p)
                sol_norm[sol_norm<threshold] = -1 
                sol_norm[sol_norm>=threshold] = 1
                pt_matrix[row_ind,column_ind] = pt_matrix[row_ind,column_ind] + relative_error(sol_norm)
    # Create sample mask.
    # Solve p-norm interpolation.
    
    # Aggregate.
    pt_matrix = pt_matrix/n_trials
    return pt_matrix

# %% [markdown]
# ### Question 17
#
# Pick 5 "m/n" ratios in $(0, 1)$ and 5 threshold levels in $(-1, 1)$ and run the `phase_transition()` function with `n_trials` = 20, for both $p = 1$ and $p = 2$.

# %%
mn_ratios = [0.2,0.4,0.6,0.7,0.8]# Your code here.

thresholds = [0,-0.5,0.5,-0.25,0.25]# Your code here.

n_trials = 20

pt_matrix_1norm = phase_transition(mn_ratios, thresholds, n_trials, labels, p=1)# Your code here.

pt_matrix_2norm = phase_transition(mn_ratios, thresholds, n_trials, labels, p=2)# Your code here.
# Out:
# Solution found after 200 iterations:
#     objective function f(sol) = 9.180205e+04
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 9.199475e+04
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 9.655359e+04
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 9.271349e+04
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 8.994546e+04
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 9.449012e+04
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 9.575631e+04
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 9.317156e+04
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 9.396418e+04
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 9.241170e+04
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 9.117054e+04
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 9.490802e+04
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 9.252798e+04
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 9.378335e+04
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 9.118873e+04
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 9.273428e+04
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 9.476501e+04
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 9.380353e+04
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 9.225872e+04
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 9.314188e+04
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 9.165542e+04
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 9.507073e+04
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 9.315521e+04
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 9.299481e+04
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 9.613201e+04
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 9.400908e+04
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 9.355148e+04
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 9.317431e+04
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 9.175183e+04
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 9.284433e+04
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 9.495705e+04
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 9.322970e+04
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 9.505775e+04
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 9.231657e+04
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 9.255499e+04
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 9.473785e+04
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 9.282773e+04
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 9.277854e+04
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 9.234456e+04
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 9.483175e+04
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 9.420132e+04
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 9.211808e+04
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 9.355678e+04
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 9.389584e+04
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 9.298602e+04
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 9.475345e+04
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 9.223391e+04
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 9.126790e+04
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 9.350927e+04
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 9.264389e+04
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 9.557973e+04
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 9.119991e+04
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 9.490177e+04
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 9.363874e+04
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 9.463360e+04
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 9.330091e+04
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 9.277318e+04
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 9.091644e+04
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 9.254302e+04
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 9.148079e+04
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 9.161159e+04
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 9.562967e+04
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 9.345060e+04
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 9.341341e+04
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 9.254903e+04
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 9.108056e+04
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 9.196836e+04
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 9.194043e+04
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 9.329790e+04
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 9.381880e+04
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 9.116172e+04
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 9.201361e+04
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 9.263257e+04
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 9.274830e+04
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 9.355957e+04
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 9.313494e+04
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 9.207015e+04
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 9.247665e+04
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 9.221115e+04
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 9.380934e+04
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 9.387887e+04
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 9.434061e+04
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 9.155183e+04
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 9.276481e+04
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 9.270400e+04
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 9.162097e+04
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 9.376876e+04
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 9.222225e+04
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 9.363829e+04
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 9.628075e+04
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 9.252804e+04
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 9.518945e+04
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 9.194505e+04
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 9.214428e+04
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 9.215377e+04
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 9.567875e+04
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 9.259293e+04
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 9.128767e+04
#     stopping criterion: MAXIT
# Solution found after 40 iterations:
#     objective function f(sol) = 4.408359e+03
#     stopping criterion: RTOL
# Solution found after 200 iterations:
#     objective function f(sol) = 9.282652e+04
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 9.048036e+04
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 9.282548e+04
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 9.238259e+04
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 9.489292e+04
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 9.135869e+04
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 9.649403e+04
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 9.427159e+04
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 9.176771e+04
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 9.226288e+04
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 9.062223e+04
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 9.408262e+04
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 9.344368e+04
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 9.412264e+04
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 9.331068e+04
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 9.170971e+04
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 9.313886e+04
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 9.604604e+04
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 9.286036e+04
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 9.428371e+04
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 9.287284e+04
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 9.064133e+04
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 9.455635e+04
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 9.276218e+04
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 9.413768e+04
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 9.263061e+04
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 9.201520e+04
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 9.545464e+04
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 9.361525e+04
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 9.742853e+04
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 9.416101e+04
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 9.328401e+04
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 9.416126e+04
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 9.323525e+04
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 9.558445e+04
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 9.311643e+04
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 9.125726e+04
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 9.295082e+04
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 9.341755e+04
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 9.514251e+04
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 9.676881e+04
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 9.274539e+04
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 9.112943e+04
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 9.083529e+04
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 9.160423e+04
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 9.221659e+04
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 9.223517e+04
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 9.231651e+04
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 9.197097e+04
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 9.537526e+04
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 9.291981e+04
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 9.294460e+04
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 9.160276e+04
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 9.378813e+04
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 9.046192e+04
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 9.489600e+04
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 9.348131e+04
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 9.318613e+04
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 9.179045e+04
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 9.321048e+04
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 9.281886e+04
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 9.210678e+04
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 9.262170e+04
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 9.244119e+04
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 9.464994e+04
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 9.612136e+04
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 9.352570e+04
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 9.360389e+04
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 9.405713e+04
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 9.068321e+04
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 9.092708e+04
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 9.170251e+04
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 9.616978e+04
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 9.267356e+04
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 9.583350e+04
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 9.204149e+04
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 9.230923e+04
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 9.350305e+04
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 9.417568e+04
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 9.375755e+04
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 9.342236e+04
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 9.306372e+04
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 9.130154e+04
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 9.518783e+04
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 9.210666e+04
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 9.189155e+04
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 9.359480e+04
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 9.212700e+04
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 9.354937e+04
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 9.140167e+04
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 9.305525e+04
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 9.205776e+04
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 9.682729e+04
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 9.171744e+04
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 9.282266e+04
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 9.385485e+04
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 9.347665e+04
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 9.141107e+04
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 9.236816e+04
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 9.231170e+04
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 9.170626e+04
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 9.554300e+04
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 9.105597e+04
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 9.018767e+04
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 9.151959e+04
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 9.271080e+04
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 9.096872e+04
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 9.273463e+04
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 9.343549e+04
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 9.164780e+04
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 9.369211e+04
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 9.250874e+04
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 9.269920e+04
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 9.119353e+04
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 9.212984e+04
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 9.421335e+04
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 9.207962e+04
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 9.223981e+04
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 9.107050e+04
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 9.113154e+04
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 9.648328e+04
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 9.227469e+04
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 9.448582e+04
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 9.053077e+04
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 9.708239e+04
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 9.312579e+04
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 9.242555e+04
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 9.151282e+04
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 9.461536e+04
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 9.406123e+04
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 9.119885e+04
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 9.376142e+04
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 9.204798e+04
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 9.370440e+04
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 9.460765e+04
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 9.222805e+04
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 9.177996e+04
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 9.437999e+04
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 9.342250e+04
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 9.313541e+04
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 9.422783e+04
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 9.312025e+04
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 9.262102e+04
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 9.323080e+04
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 9.359974e+04
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 9.336245e+04
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 9.420593e+04
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 9.498478e+04
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 9.377463e+04
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 9.406180e+04
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 9.296369e+04
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 9.263959e+04
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 9.538331e+04
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 9.339852e+04
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 9.440233e+04
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 9.278983e+04
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 9.574773e+04
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 9.385031e+04
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 9.216407e+04
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 9.405137e+04
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 9.219917e+04
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 9.192782e+04
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 9.305333e+04
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 9.197805e+04
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 9.497030e+04
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 9.360130e+04
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 9.154674e+04
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 9.120739e+04
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 9.557705e+04
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 9.098310e+04
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 9.466597e+04
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 9.343118e+04
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 9.377950e+04
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 9.418400e+04
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 9.269278e+04
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 8.972927e+04
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 9.513665e+04
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 8.942229e+04
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 9.252063e+04
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 9.351471e+04
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 9.219038e+04
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 9.236785e+04
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 9.468953e+04
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 9.360039e+04
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 9.174903e+04
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 9.313218e+04
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 9.098376e+04
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 9.317621e+04
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 9.462217e+04
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 9.401473e+04
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 9.472515e+04
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 9.241637e+04
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 9.426472e+04
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 9.153800e+04
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 9.362411e+04
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 9.348466e+04
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 9.512034e+04
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 9.334987e+04
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 8.904919e+04
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 9.450507e+04
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 8.889143e+04
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 9.071342e+04
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 9.063895e+04
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 9.497889e+04
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 9.433631e+04
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 9.166882e+04
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 9.246933e+04
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 9.248116e+04
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 9.439748e+04
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 9.183490e+04
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 9.277293e+04
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 9.158374e+04
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 9.203268e+04
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 9.373440e+04
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 9.354402e+04
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 9.020599e+04
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 9.272935e+04
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 9.500749e+04
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 9.331441e+04
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 9.324481e+04
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 9.171396e+04
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 9.242617e+04
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 9.448000e+04
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 9.242948e+04
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 9.402785e+04
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 9.512207e+04
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 9.312620e+04
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 9.491129e+04
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 9.079280e+04
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 9.765742e+04
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 9.171043e+04
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 9.177321e+04
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 9.169723e+04
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 9.380063e+04
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 9.430982e+04
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 9.417969e+04
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 9.168224e+04
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 9.424361e+04
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 9.354191e+04
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 9.477364e+04
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 9.482937e+04
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 9.470738e+04
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 9.439436e+04
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 9.165890e+04
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 9.437423e+04
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 9.297540e+04
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 9.305403e+04
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 9.402390e+04
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 9.217776e+04
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 9.307106e+04
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 9.539881e+04
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 9.093870e+04
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 9.494265e+04
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 9.302365e+04
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 9.422319e+04
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 9.375091e+04
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 9.628513e+04
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 9.540446e+04
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 9.240219e+04
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 9.299645e+04
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 9.480659e+04
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 9.251252e+04
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 9.401616e+04
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 9.299067e+04
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 9.235419e+04
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 9.215140e+04
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 9.260885e+04
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 9.320307e+04
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 9.202471e+04
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 9.360929e+04
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 9.131040e+04
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 9.355558e+04
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 9.424109e+04
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 9.173250e+04
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 9.395243e+04
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 9.227917e+04
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 9.387111e+04
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 9.377224e+04
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 9.242427e+04
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 9.488746e+04
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 9.538651e+04
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 9.349750e+04
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 9.350672e+04
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 9.281246e+04
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 8.890413e+04
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 9.679363e+04
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 9.278062e+04
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 9.408183e+04
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 9.368960e+04
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 9.366688e+04
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 9.142085e+04
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 9.319742e+04
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 9.354002e+04
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 9.613807e+04
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 9.126453e+04
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 9.565116e+04
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 9.360961e+04
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 9.339327e+04
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 9.159802e+04
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 9.193679e+04
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 9.243746e+04
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 9.075258e+04
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 9.474724e+04
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 9.413605e+04
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 9.355978e+04
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 9.181756e+04
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 9.245347e+04
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 9.498513e+04
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 9.048011e+04
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 9.188714e+04
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 9.391744e+04
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 9.443305e+04
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 9.424694e+04
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 9.357570e+04
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 9.377077e+04
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 9.608703e+04
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 9.452508e+04
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 9.291075e+04
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 9.019835e+04
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 9.239150e+04
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 9.193405e+04
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 9.111097e+04
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 9.519680e+04
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 9.260629e+04
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 9.328348e+04
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 9.407495e+04
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 9.286173e+04
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 8.989489e+04
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 9.423556e+04
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
# ...
#     objective function f(sol) = 1.632229e+03
#     stopping criterion: RTOL
# Solution found after 129 iterations:
#     objective function f(sol) = 1.700429e+03
#     stopping criterion: RTOL
# Solution found after 127 iterations:
#     objective function f(sol) = 1.768100e+03
#     stopping criterion: RTOL
# Solution found after 114 iterations:
#     objective function f(sol) = 1.737736e+03
#     stopping criterion: RTOL
# Solution found after 139 iterations:
#     objective function f(sol) = 1.714581e+03
#     stopping criterion: RTOL
# Solution found after 123 iterations:
#     objective function f(sol) = 1.726560e+03
#     stopping criterion: RTOL
# Solution found after 132 iterations:
#     objective function f(sol) = 1.757516e+03
#     stopping criterion: RTOL
# Solution found after 44 iterations:
#     objective function f(sol) = 1.952496e+03
#     stopping criterion: RTOL
# Solution found after 67 iterations:
#     objective function f(sol) = 1.923015e+03
#     stopping criterion: RTOL
# Solution found after 107 iterations:
#     objective function f(sol) = 1.775080e+03
#     stopping criterion: RTOL
# Solution found after 155 iterations:
#     objective function f(sol) = 1.638942e+03
#     stopping criterion: RTOL
# Solution found after 74 iterations:
#     objective function f(sol) = 1.821389e+03
#     stopping criterion: RTOL
# Solution found after 65 iterations:
#     objective function f(sol) = 1.901494e+03
#     stopping criterion: RTOL
# Solution found after 97 iterations:
#     objective function f(sol) = 1.842323e+03
#     stopping criterion: RTOL
# Solution found after 76 iterations:
#     objective function f(sol) = 1.827701e+03
#     stopping criterion: RTOL
# Solution found after 128 iterations:
#     objective function f(sol) = 1.718706e+03
#     stopping criterion: RTOL
# Solution found after 149 iterations:
#     objective function f(sol) = 1.804235e+03
#     stopping criterion: RTOL
# Solution found after 22 iterations:
#     objective function f(sol) = 1.912592e+03
#     stopping criterion: RTOL
# Solution found after 65 iterations:
#     objective function f(sol) = 1.794152e+03
#     stopping criterion: RTOL
# Solution found after 116 iterations:
#     objective function f(sol) = 1.801692e+03
#     stopping criterion: RTOL
# Solution found after 108 iterations:
#     objective function f(sol) = 1.765441e+03
#     stopping criterion: RTOL
# Solution found after 74 iterations:
#     objective function f(sol) = 1.939272e+03
#     stopping criterion: RTOL
# Solution found after 72 iterations:
#     objective function f(sol) = 1.742956e+03
#     stopping criterion: RTOL
# Solution found after 112 iterations:
#     objective function f(sol) = 1.789287e+03
#     stopping criterion: RTOL
# Solution found after 151 iterations:
#     objective function f(sol) = 1.710772e+03
#     stopping criterion: RTOL
# Solution found after 103 iterations:
#     objective function f(sol) = 1.901616e+03
#     stopping criterion: RTOL
# Solution found after 104 iterations:
#     objective function f(sol) = 1.772247e+03
#     stopping criterion: RTOL
# Solution found after 87 iterations:
#     objective function f(sol) = 2.007038e+03
#     stopping criterion: RTOL
# Solution found after 41 iterations:
#     objective function f(sol) = 1.953198e+03
#     stopping criterion: RTOL
# Solution found after 117 iterations:
#     objective function f(sol) = 1.797656e+03
#     stopping criterion: RTOL
# Solution found after 93 iterations:
#     objective function f(sol) = 1.781025e+03
#     stopping criterion: RTOL
# Solution found after 109 iterations:
#     objective function f(sol) = 1.729857e+03
#     stopping criterion: RTOL
# Solution found after 124 iterations:
#     objective function f(sol) = 1.683063e+03
#     stopping criterion: RTOL
# Solution found after 118 iterations:
#     objective function f(sol) = 1.807024e+03
#     stopping criterion: RTOL
# Solution found after 1 iterations:
#     objective function f(sol) = 1.955705e+03
#     stopping criterion: RTOL
# Solution found after 110 iterations:
#     objective function f(sol) = 1.852578e+03
#     stopping criterion: RTOL
# Solution found after 133 iterations:
#     objective function f(sol) = 1.799653e+03
#     stopping criterion: RTOL
# Solution found after 145 iterations:
#     objective function f(sol) = 1.740566e+03
#     stopping criterion: RTOL
# Solution found after 58 iterations:
#     objective function f(sol) = 1.926026e+03
#     stopping criterion: RTOL
# Solution found after 151 iterations:
#     objective function f(sol) = 1.767232e+03
#     stopping criterion: RTOL
# Solution found after 116 iterations:
#     objective function f(sol) = 1.744853e+03
#     stopping criterion: RTOL
# Solution found after 80 iterations:
#     objective function f(sol) = 1.902516e+03
#     stopping criterion: RTOL
# Solution found after 93 iterations:
#     objective function f(sol) = 1.709441e+03
#     stopping criterion: RTOL
# Solution found after 125 iterations:
#     objective function f(sol) = 1.781240e+03
#     stopping criterion: RTOL
# Solution found after 83 iterations:
#     objective function f(sol) = 1.823984e+03
#     stopping criterion: RTOL
# Solution found after 95 iterations:
#     objective function f(sol) = 1.780423e+03
#     stopping criterion: RTOL
# Solution found after 91 iterations:
#     objective function f(sol) = 1.768699e+03
#     stopping criterion: RTOL
# Solution found after 101 iterations:
#     objective function f(sol) = 1.849890e+03
#     stopping criterion: RTOL
# Solution found after 84 iterations:
#     objective function f(sol) = 1.685936e+03
#     stopping criterion: RTOL
# Solution found after 75 iterations:
#     objective function f(sol) = 2.062615e+03
#     stopping criterion: RTOL
# Solution found after 105 iterations:
#     objective function f(sol) = 1.714004e+03
#     stopping criterion: RTOL
# Solution found after 139 iterations:
#     objective function f(sol) = 1.873900e+03
#     stopping criterion: RTOL
# Solution found after 38 iterations:
#     objective function f(sol) = 1.940655e+03
#     stopping criterion: RTOL
# Solution found after 71 iterations:
#     objective function f(sol) = 1.836516e+03
#     stopping criterion: RTOL
# Solution found after 115 iterations:
#     objective function f(sol) = 1.851150e+03
#     stopping criterion: RTOL
# Solution found after 78 iterations:
#     objective function f(sol) = 1.899573e+03
#     stopping criterion: RTOL
# Solution found after 83 iterations:
#     objective function f(sol) = 1.845340e+03
#     stopping criterion: RTOL
# Solution found after 125 iterations:
#     objective function f(sol) = 1.771760e+03
#     stopping criterion: RTOL
# Solution found after 142 iterations:
#     objective function f(sol) = 1.773623e+03
#     stopping criterion: RTOL
# Solution found after 78 iterations:
#     objective function f(sol) = 1.839279e+03
#     stopping criterion: RTOL
# Solution found after 135 iterations:
#     objective function f(sol) = 1.710573e+03
#     stopping criterion: RTOL
# Solution found after 117 iterations:
#     objective function f(sol) = 1.718597e+03
#     stopping criterion: RTOL
# Solution found after 73 iterations:
#     objective function f(sol) = 1.899162e+03
#     stopping criterion: RTOL
# Solution found after 109 iterations:
#     objective function f(sol) = 1.694138e+03
#     stopping criterion: RTOL
# Solution found after 98 iterations:
#     objective function f(sol) = 1.782801e+03
#     stopping criterion: RTOL
# Solution found after 86 iterations:
#     objective function f(sol) = 1.732988e+03
#     stopping criterion: RTOL
# Solution found after 110 iterations:
#     objective function f(sol) = 1.642184e+03
#     stopping criterion: RTOL
# Solution found after 90 iterations:
#     objective function f(sol) = 1.747397e+03
#     stopping criterion: RTOL
# Solution found after 95 iterations:
#     objective function f(sol) = 1.743099e+03
#     stopping criterion: RTOL
# Solution found after 96 iterations:
#     objective function f(sol) = 1.813813e+03
#     stopping criterion: RTOL
# Solution found after 76 iterations:
#     objective function f(sol) = 1.889680e+03
#     stopping criterion: RTOL
# Solution found after 78 iterations:
#     objective function f(sol) = 1.820118e+03
#     stopping criterion: RTOL
# Solution found after 136 iterations:
#     objective function f(sol) = 1.789859e+03
#     stopping criterion: RTOL
# Solution found after 95 iterations:
#     objective function f(sol) = 1.815858e+03
#     stopping criterion: RTOL
# Solution found after 177 iterations:
#     objective function f(sol) = 1.633378e+03
#     stopping criterion: RTOL
# Solution found after 116 iterations:
#     objective function f(sol) = 1.771534e+03
#     stopping criterion: RTOL
# Solution found after 81 iterations:
#     objective function f(sol) = 1.831562e+03
#     stopping criterion: RTOL
# Solution found after 132 iterations:
#     objective function f(sol) = 1.647473e+03
#     stopping criterion: RTOL
# Solution found after 87 iterations:
#     objective function f(sol) = 1.778928e+03
#     stopping criterion: RTOL
# Solution found after 61 iterations:
#     objective function f(sol) = 1.840855e+03
#     stopping criterion: RTOL
# Solution found after 114 iterations:
#     objective function f(sol) = 1.831648e+03
#     stopping criterion: RTOL
# Solution found after 162 iterations:
#     objective function f(sol) = 1.653475e+03
#     stopping criterion: RTOL
# Solution found after 178 iterations:
#     objective function f(sol) = 1.624795e+03
#     stopping criterion: RTOL
# Solution found after 71 iterations:
#     objective function f(sol) = 1.893921e+03
#     stopping criterion: RTOL
# Solution found after 111 iterations:
#     objective function f(sol) = 1.615587e+03
#     stopping criterion: RTOL
# Solution found after 53 iterations:
#     objective function f(sol) = 1.914126e+03
#     stopping criterion: RTOL
# Solution found after 96 iterations:
#     objective function f(sol) = 1.802155e+03
#     stopping criterion: RTOL
# Solution found after 129 iterations:
#     objective function f(sol) = 1.747163e+03
#     stopping criterion: RTOL
# Solution found after 86 iterations:
#     objective function f(sol) = 1.864512e+03
#     stopping criterion: RTOL
# Solution found after 50 iterations:
#     objective function f(sol) = 1.896942e+03
#     stopping criterion: RTOL
# Solution found after 89 iterations:
#     objective function f(sol) = 1.869494e+03
#     stopping criterion: RTOL
# Solution found after 47 iterations:
#     objective function f(sol) = 1.817471e+03
#     stopping criterion: RTOL
# Solution found after 3 iterations:
#     objective function f(sol) = 2.038376e+03
#     stopping criterion: RTOL
# Solution found after 140 iterations:
#     objective function f(sol) = 1.629739e+03
#     stopping criterion: RTOL
# Solution found after 102 iterations:
#     objective function f(sol) = 1.804690e+03
#     stopping criterion: RTOL
# Solution found after 87 iterations:
#     objective function f(sol) = 1.870363e+03
#     stopping criterion: RTOL
# Solution found after 127 iterations:
#     objective function f(sol) = 1.713211e+03
#     stopping criterion: RTOL
# Solution found after 118 iterations:
#     objective function f(sol) = 1.681419e+03
#     stopping criterion: RTOL
# Solution found after 115 iterations:
#     objective function f(sol) = 1.747081e+03
#     stopping criterion: RTOL
# Solution found after 129 iterations:
#     objective function f(sol) = 1.802734e+03
#     stopping criterion: RTOL
# Solution found after 98 iterations:
#     objective function f(sol) = 1.853167e+03
#     stopping criterion: RTOL
# Solution found after 88 iterations:
#     objective function f(sol) = 1.821153e+03
#     stopping criterion: RTOL
# Solution found after 124 iterations:
#     objective function f(sol) = 1.773964e+03
#     stopping criterion: RTOL
# Solution found after 48 iterations:
#     objective function f(sol) = 1.874044e+03
#     stopping criterion: RTOL
# Solution found after 103 iterations:
#     objective function f(sol) = 1.680017e+03
#     stopping criterion: RTOL
# Solution found after 34 iterations:
#     objective function f(sol) = 1.888655e+03
#     stopping criterion: RTOL
# Solution found after 46 iterations:
#     objective function f(sol) = 1.839254e+03
#     stopping criterion: RTOL
# Solution found after 147 iterations:
#     objective function f(sol) = 1.773839e+03
#     stopping criterion: RTOL
# Solution found after 53 iterations:
#     objective function f(sol) = 1.800429e+03
#     stopping criterion: RTOL
# Solution found after 96 iterations:
#     objective function f(sol) = 1.869258e+03
#     stopping criterion: RTOL
# Solution found after 42 iterations:
#     objective function f(sol) = 1.836605e+03
#     stopping criterion: RTOL
# Solution found after 90 iterations:
#     objective function f(sol) = 1.853141e+03
#     stopping criterion: RTOL
# Solution found after 175 iterations:
#     objective function f(sol) = 1.662731e+03
#     stopping criterion: RTOL
# Solution found after 81 iterations:
#     objective function f(sol) = 1.895058e+03
#     stopping criterion: RTOL
# Solution found after 79 iterations:
#     objective function f(sol) = 1.709910e+03
#     stopping criterion: RTOL
# Solution found after 85 iterations:
#     objective function f(sol) = 1.955641e+03
#     stopping criterion: RTOL
# Solution found after 47 iterations:
#     objective function f(sol) = 1.914896e+03
#     stopping criterion: RTOL
# Solution found after 99 iterations:
#     objective function f(sol) = 1.698187e+03
#     stopping criterion: RTOL
# Solution found after 87 iterations:
#     objective function f(sol) = 1.889232e+03
#     stopping criterion: RTOL
# Solution found after 108 iterations:
#     objective function f(sol) = 1.857432e+03
#     stopping criterion: RTOL
# Solution found after 70 iterations:
#     objective function f(sol) = 1.848825e+03
#     stopping criterion: RTOL
# Solution found after 111 iterations:
#     objective function f(sol) = 1.799739e+03
#     stopping criterion: RTOL
# Solution found after 142 iterations:
#     objective function f(sol) = 1.777150e+03
#     stopping criterion: RTOL
# Solution found after 164 iterations:
#     objective function f(sol) = 1.739666e+03
#     stopping criterion: RTOL
# Solution found after 98 iterations:
#     objective function f(sol) = 1.685453e+03
#     stopping criterion: RTOL
# Solution found after 71 iterations:
#     objective function f(sol) = 1.830440e+03
#     stopping criterion: RTOL
# Solution found after 102 iterations:
#     objective function f(sol) = 1.760216e+03
#     stopping criterion: RTOL
# Solution found after 124 iterations:
#     objective function f(sol) = 1.738856e+03
#     stopping criterion: RTOL
# Solution found after 133 iterations:
#     objective function f(sol) = 1.767401e+03
#     stopping criterion: RTOL
# Solution found after 75 iterations:
#     objective function f(sol) = 1.917642e+03
#     stopping criterion: RTOL
# Solution found after 72 iterations:
#     objective function f(sol) = 1.784119e+03
#     stopping criterion: RTOL
# Solution found after 112 iterations:
#     objective function f(sol) = 1.772238e+03
#     stopping criterion: RTOL
# Solution found after 32 iterations:
#     objective function f(sol) = 2.028879e+03
#     stopping criterion: RTOL
# Solution found after 184 iterations:
#     objective function f(sol) = 1.675139e+03
#     stopping criterion: RTOL
# Solution found after 72 iterations:
#     objective function f(sol) = 1.897762e+03
#     stopping criterion: RTOL
# Solution found after 50 iterations:
#     objective function f(sol) = 1.891734e+03
#     stopping criterion: RTOL
# Solution found after 147 iterations:
#     objective function f(sol) = 1.647832e+03
#     stopping criterion: RTOL
# Solution found after 76 iterations:
#     objective function f(sol) = 1.714240e+03
#     stopping criterion: RTOL
# Solution found after 12 iterations:
#     objective function f(sol) = 2.037020e+03
#     stopping criterion: RTOL
# Solution found after 54 iterations:
#     objective function f(sol) = 1.849415e+03
#     stopping criterion: RTOL
# Solution found after 73 iterations:
#     objective function f(sol) = 1.915824e+03
#     stopping criterion: RTOL
# Solution found after 145 iterations:
#     objective function f(sol) = 1.637215e+03
#     stopping criterion: RTOL
# Solution found after 106 iterations:
#     objective function f(sol) = 1.890796e+03
#     stopping criterion: RTOL
# Solution found after 106 iterations:
#     objective function f(sol) = 1.730231e+03
#     stopping criterion: RTOL
# Solution found after 63 iterations:
#     objective function f(sol) = 1.794059e+03
#     stopping criterion: RTOL

# %% [markdown]
# Plot both phase transition matrices as images with a colorbar. Make sure to properly name the axes and title the images.

# %%
# Your code here.
fig = plt.figure()
plt.imshow(pt_matrix_1norm)
plt.title('Phase Transition 1-norm minimization')
plt.show()
plt.close(fig)

fig = plt.figure()
plt.imshow(pt_matrix_2norm)
plt.title('Phase Transition 2-norm minimization')
plt.show()
plt.close(fig)

# %% [markdown]
# ### Question 18
#
# Do the phase transition plots above provide any justification for choosing one $p-$norm interpolation over the other? Why?

# %% [markdown]
# **Your answer here.**
